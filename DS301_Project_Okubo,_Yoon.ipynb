# %% [markdown]
# # **CODE SETUP (importing basic packages, reading data)**

# %%
#Installing missing packages
# !pip install yfinance
# !pip install poloniex
# !pip install enviroment

# !pip install tensorflow
# !pip install tf_agents
# !pip install keras
# !pip install keras-rl2

# !pip install process_data
# !pip install normalizer

# !pip install random
# !pip install gym
# !pip install math
# !pip install pathlib
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.70-py2.py3-none-any.whl (26 kB)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 6.0 MB/s
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Collecting requests>=2.26
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 366 kB/s
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Installing collected packages: requests, lxml, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed lxml-4.8.0 requests-2.27.1 yfinance-0.1.70
# Collecting poloniex
#   Downloading poloniex-0.0.17-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from poloniex) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from poloniex) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->poloniex) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->poloniex) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests->poloniex) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->poloniex) (2.10)
# Installing collected packages: poloniex
# Successfully installed poloniex-0.0.17
# ERROR: Could not find a version that satisfies the requirement enviroment (from versions: none)
# ERROR: No matching distribution found for enviroment
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.44.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (4.2.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.25.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 8.3 MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow) (1.5.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.27.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# Installing collected packages: tf-estimator-nightly
# Successfully installed tf-estimator-nightly-2.8.0.dev2021122109
# Collecting tf_agents
#   Downloading tf_agents-0.12.1-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 7.2 MB/s
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (1.3.0)
# Requirement already satisfied: absl-py>=0.6.1 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (1.0.0)
# Collecting pygame==2.1.0
#   Downloading pygame-2.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      |████████████████████████████████| 18.3 MB 1.3 MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (1.15.0)
# Requirement already satisfied: tensorflow-probability>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (0.16.0)
# Requirement already satisfied: gin-config>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (0.5.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (1.21.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from tf_agents) (7.1.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (1.14.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (4.2.0)
# Requirement already satisfied: gym>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (0.17.3)
# Requirement already satisfied: protobuf>=3.11.3 in /usr/local/lib/python3.7/dist-packages (from tf_agents) (3.17.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym>=0.17.0->tf_agents) (1.4.1)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym>=0.17.0->tf_agents) (1.5.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym>=0.17.0->tf_agents) (0.16.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability>=0.16.0->tf_agents) (0.1.7)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability>=0.16.0->tf_agents) (4.4.2)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability>=0.16.0->tf_agents) (0.5.3)
# Installing collected packages: pygame, tf-agents
# Successfully installed pygame-2.1.0 tf-agents-0.12.1
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.8.0)
# Collecting keras-rl2
#   Downloading keras_rl2-1.0.5-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 958 kB/s
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from keras-rl2) (2.8.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.44.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.15.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.0.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (2.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (57.4.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (4.2.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (2.8.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (14.0.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (0.25.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (3.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (3.17.3)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.14.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (3.3.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.21.6)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (0.5.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (1.6.3)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-rl2) (2.8.0.dev2021122109)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow->keras-rl2) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow->keras-rl2) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (3.3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (1.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (2.27.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->keras-rl2) (3.2.0)
# Installing collected packages: keras-rl2
# Successfully installed keras-rl2-1.0.5
# Collecting process_data
#   Downloading process_data-0.3-py3-none-any.whl (3.5 kB)
# Installing collected packages: process-data
# Successfully installed process-data-0.3
# Collecting normalizer
#   Downloading normalizer-0.2.1.tar.gz (3.3 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from normalizer) (57.4.0)
# Building wheels for collected packages: normalizer
#   Building wheel for normalizer (setup.py) ... done
#   Created wheel for normalizer: filename=normalizer-0.2.1-py3-none-any.whl size=3755 sha256=2d64f397b0884095554baecfc0cf6e132de1e24854c35f47757113a12e5ce5fd
#   Stored in directory: /root/.cache/pip/wheels/55/98/a5/aa1e30f747bd0428d27d08735f1d72726ac8ed4e543476f0d3
# Successfully built normalizer
# Installing collected packages: normalizer
# Successfully installed normalizer-0.2.1
# ERROR: Could not find a version that satisfies the requirement random (from versions: none)
# ERROR: No matching distribution found for random
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (0.17.3)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym) (1.21.6)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)
# ERROR: Could not find a version that satisfies the requirement math (from versions: none)
# ERROR: No matching distribution found for math
# Requirement already satisfied: pathlib in /usr/local/lib/python3.7/dist-packages (1.0.1)

# %%
# Basic Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import yfinance as yf
import datetime

# %%
#Setting up dates
start = datetime.datetime(2020,1,1) 
end = datetime.datetime(2021,11,30)

# %% [markdown]
# # **BTC Data Import and Normalization**
# Sorry can't the github ref we're using doesn't show how to normalize using yfinance; it uses poloniex. Feel free to change this part tho if u find a way to normalize the data !!!

# %%
# Getting BTC Data from Poloniex

from poloniex import Poloniex
from time import time
polo = Poloniex()

# period = 1800 means 30 min intervals; period = 3600 means 1 hr intervals
# x in start=int(time()) - 60 * 60 * 24 *30 * x) is no. of months

# Test data -- getting 3 months of data from present 
candles = polo.returnChartData('USDT_BTC', period=1800, start=int(time()) - 60 * 60 * 24 *30 * 3)

# Train data -- getting 12 months of data from start of test 
# candles = polo.returnChartData('USDT_BTC', period=1800, start=int(time()) - 60 * 60 * 24 *30 * 15, 
#                                end=int(time()) - 60 * 60 * 24 *30 * 3)

df = pd.DataFrame.from_dict(candles)
dates = pd.to_datetime(df['date'],unit='s')

results = pd.DataFrame(dates.apply(lambda x: x.strftime('%Y-%m-%d %I-%p')))
results['close'] = df.close
results['open'] = df.open
results['low'] = df.low
results['high'] = df.high
results['volume'] = df.volume
results.to_csv('/content/data/test/BTC_USD_30min.csv')

# %%
# Normalizing the Data using sklearn

from rl.core import Processor
from rl.util import WhiteningNormalizer
from sklearn.preprocessing import MinMaxScaler, StandardScaler

ADDITIONAL_STATE = 4
# class NormalizerProcessor(Processor):
class NormalizerProcessor:
    def __init__(self):
        self.scaler = StandardScaler()
        self.normalizer = None

    def process_state_batch(self, batch):
        batch_len = batch.shape[0]
        k = []
        for i in range(batch_len):
            observe = batch[i][..., :-ADDITIONAL_STATE]
            observe = self.scaler.fit_transform(observe)
            agent_state = batch[i][..., -ADDITIONAL_STATE:]
            temp = np.concatenate((observe, agent_state),axis=1)
            temp = temp.reshape((1,) + temp.shape)
            k.append(temp)
        batch = np.concatenate(tuple(k))
        return batch

# %% [markdown]
# # **Feature Extraction**

# %%
# Extracting features from the data

from sklearn.preprocessing import MinMaxScaler

class FeatureExtractor:
    def __init__(self, df):
       self.df = df
       self.open = df['open'].astype('float')
       self.close = df['close'].astype('float')
       self.high = df['high'].astype('float')
       self.low = df['low'].astype('float')
       self.volume = df['volume'].astype('float')

    def add_bar_features(self):
        #stationary candle
        self.df['bar_hc'] = self.high - self.close
        self.df['bar_ho'] = self.high - self.open
        self.df['bar_hl'] = self.high - self.low
        self.df['bar_cl'] = self.close - self.low
        self.df['bar_ol'] = self.open - self.low
        self.df['bar_co'] = self.close - self.open
        self.df['ret_mean'] = self.df['close'].rolling(50).mean() - self.df['close']
        self.df['ret_std'] = self.df['ret_mean']/self.df['ret_mean'].rolling(50).std()
        #self.df['bar_mov3'] = self.df['close'] - self.df['close'].shift(3)
        #self.df['bar_mov9'] = self.df['close'] - self.df['close'].shift(9)
        return self.df

# %% [markdown]
# # **Creating the model environment (trading rules, helper functions)**

# %%
import process_data
import random
import gym
from gym import spaces
from gym.utils import seeding
import math
from pathlib import Path

# position constant
LONG = 0
FLAT = 2

# action constant
BUY = 0
SELL = 1
HOLD = 2

# %%
class OhlcvEnv(gym.Env):
    def __init__(self, window_size, path, show_trade=True):
        self.show_trade = show_trade
        self.path = path
        self.actions = ["BUY",  "SELL", "HOLD"]
        self.fee = 0.0005
        self.seed()
        self.file_list = []
        # load_csv
        self.load_from_csv()

        # n_features
        self.window_size = window_size
        self.n_features = self.df.shape[1]
        self.shape = (self.window_size, self.n_features+4)

        # defines action space
        self.action_space = spaces.Discrete(len(self.actions))
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=self.shape, dtype=np.float32)

    # data is taken from https://www.cryptodatadownload.com/data/northamerican/
    def load_from_csv(self):
        if(len(self.file_list) == 0):
            self.file_list = [x.name for x in Path(self.path).iterdir() if x.is_file()]
            self.file_list.sort()
        self.rand_episode = self.file_list.pop()
        
        dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')

        raw_df= pd.read_csv(self.path + self.rand_episode, 
            parse_dates=['date'], date_parser=dateparse)

        raw_df = raw_df.sort_values(by='date').reset_index(drop=True)
        #extractor = process_data.FeatureExtractor(raw_df)
        extractor = FeatureExtractor(raw_df)
        self.df = extractor.add_bar_features() # bar features o, h, l, c ---> C(4,2) = 4*3/2*1 = 6 features

        ## selected manual fetuares
        feature_list = [
            'bar_hc',
            'bar_ho',
            'bar_hl',
            'bar_cl',
            'bar_ol',
            'bar_co', 'ret_std']
        #feature_list = ['ret_std']
        self.df.dropna(inplace=True) # drops Nan rows
        self.closingPrices = self.df['close'].values
        self.returnStd = self.df['ret_std'].values
        self.dates = self.df['date'].values
        self.df = self.df[feature_list].values

    def render(self, mode='human', verbose=False):
        return None

    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def step(self, action):

        if self.done:
            return self.state, self.reward, self.done, {}
        self.reward = 0

        self.closingPrice = float(self.closingPrices[self.current_tick])
        self.datetime= self.dates[self.current_tick]

        # action comes from the agent
        # 0 buy, 1 sell, 2 hold
        # single position can be opened per trade
        # valid action sequence would be
        # LONG : buy - hold - hold - sell
        # invalid action sequence is just considered hold
        # (e.g.) "buy - buy" would be considred "buy - hold"
        self.action = HOLD  # hold
        if action == BUY: # buy
            if self.position == FLAT: # if previous position was flat
                self.position = LONG # update position to long
                self.action = BUY # record action as buy
                self.entry_price = self.closingPrice # maintain entry price
        elif action == SELL: # vice versa for short trade
            if  self.position == LONG:
                self.position = FLAT
                self.action = SELL
                self.exit_price = self.closingPrice
                self.reward += ((self.exit_price - self.entry_price)/self.entry_price + 1)*(1-self.fee)**2 - 1
                self.krw_balance = self.krw_balance * (1.0 + self.reward)
                self.n_long += 1
                self.entry_price = 0

        # [coin + krw_won] total value evaluated in krw won
        if(self.position == LONG):
            temp_reward = ((self.closingPrice - self.entry_price)/self.entry_price + 1)*(1-self.fee)**2 - 1
            new_portfolio = self.krw_balance * (1.0 + temp_reward)
        else:
            temp_reward = 0
            new_portfolio = self.krw_balance

        self.portfolio = new_portfolio
        self.current_tick += 1
        if(self.show_trade and self.current_tick%100 == 0):
            print("Tick: {0}/ Portfolio (krw-won): {1}".format(self.current_tick, self.portfolio))
            print("Long: {0}".format(self.n_long))
        self.updateState()
        self.history.append((self.action, self.datetime, self.closingPrice, self.portfolio, self.reward))
        if (self.current_tick > (self.df.shape[0]) - self.window_size-1):
            self.done = True
            self.reward = self.get_profit() # return reward at end of the game
        return self.state, self.reward, self.done, {}

    def get_profit(self):
        if(self.position == LONG):
            profit = ((self.closingPrice - self.entry_price)/self.entry_price + 1)*(1-self.fee)**2 - 1
        else:
            profit = 0
        return profit

    def reset(self):
        # self.current_tick = random.randint(0, self.df.shape[0]-1000)
        self.current_tick = 0
        print("start episode ... {0} at {1}" .format(self.rand_episode, self.current_tick))

        # positions
        self.n_long = 0

        # clear internal variables
        self.history = [] # keep buy, sell, hold action history
        self.krw_balance =  10000 # initial balance, u can change it to whatever u like
        self.portfolio = float(self.krw_balance) # (coin * current_price + current_krw_balance) == portfolio
        self.profit = 0

        self.action = HOLD
        self.position = FLAT
        self.done = False

        self.updateState() # returns observed_features +  opened position(LONG/SHORT/FLAT) + profit_earned(during opened position)
        return self.state

    def updateState(self):
        def one_hot_encode(x, n_classes):
            return np.eye(n_classes)[x]
        prev_position = self.position
        one_hot_position = one_hot_encode(prev_position,len(self.actions))
        profit = self.get_profit()
        # append two
        self.state = np.concatenate((self.df[self.current_tick], one_hot_position, [profit]))
        return self.state

    def save_history(self, name = 'trade_history.csv'):
        df = pd.DataFrame(self.history, columns=['action','ts','price','portfolio','reward'])
        df.to_csv(name)

# %% [markdown]
# # **Main Code**

# %%
# import keras
# from keras.models import Sequential
# from keras.layers import Dense, Activation, Flatten, CuDNNLSTM, LSTM, Conv1D, MaxPooling1D
# from keras.optimizers import Adam

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, LSTM, Conv1D, MaxPooling1D
from tensorflow.compat.v1.keras.layers import CuDNNLSTM
from tensorflow.keras.optimizers import Adam

# keras-rl agent
import keras
from rl.agents.dqn import DQNAgent
# from tf_agents.agents.dqn import dqn_agent
from rl.policy import BoltzmannQPolicy, EpsGreedyQPolicy, LinearAnnealedPolicy
from rl.memory import SequentialMemory

# Obsolete -- find new
# trader environment
# from enviroment import OhlcvEnv
# custom normalizer
# from normalizer import NormalizerProcessor

def create_model(shape, nb_actions):
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size=6, padding="same", activation="tanh",input_shape=shape))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(filters=32, kernel_size=3, padding="same", activation="tanh"))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    #model.add(Dense(nb_actions, activation='sigmoid'))
    model.add(Dense(nb_actions, activation='softmax'))
    return model

def main():
    # OPTIONS
    ENV_NAME = 'OHLCV-v0'
    TIME_STEP = 20

    # Get the environment and extract the number of actions.
    PATH_TRAIN = "./data/train/"
    PATH_TEST = "./data/test/"
    env = OhlcvEnv(TIME_STEP, path=PATH_TRAIN)
    env_test = OhlcvEnv(TIME_STEP, path=PATH_TEST)

    # random seed
    np.random.seed(123)
    env.seed(123)

    nb_actions = env.action_space.n
    model = create_model(shape=env.shape, nb_actions=nb_actions)
    print(model.summary())

    # Finally, we configure and compile our agent. You can use every built-in Keras optimizer and even the metrics!
    memory = SequentialMemory(limit=1000, window_length=TIME_STEP)
    # policy = BoltzmannQPolicy()
    policy = LinearAnnealedPolicy(EpsGreedyQPolicy(),
            attr='eps', value_max=1., value_min=.2, value_test=.05, nb_steps=3000)
    # policy = EpsGreedyQPolicy()

    # enable the dueling network
    # you can specify the dueling_type to one of {'avg','max','naive'}
    dqn = DQNAgent(model=model, nb_actions=nb_actions, memory=memory, nb_steps_warmup=200,
                   enable_dueling_network=True, dueling_type='avg', target_model_update=1e-2, policy=policy)
                    # processor=NormalizerProcessor())

    # dqn = DQNAgent(model=model, nb_actions=nb_actions, memory=memory, nb_steps_warmup=200,
    #            target_model_update=1e-2, policy=policy)
    dqn.compile(Adam(lr=1e-3), metrics=['crossentropy'])

    while True:
        # train
        # dqn.load_weights('model/duel_dqn_weights-a-2.h5f')
        dqn.fit(env, nb_steps=17511 * 10, nb_max_episode_steps=17511,
          visualize=False, verbose=2)
        # dqn.save_weights('model/duel_dqn_weights-a-2.h5f', overwrite=True)
        #try:
            # validate
        info = dqn.test(env_test, nb_episodes=1, visualize=True)

        env.save_history()
        # n_long, n_short, total_reward, portfolio = info['n_trades']['long'], info['n_trades']['short'], info[
        #     'total_reward'], int(info['portfolio'])
        # np.array([info]).dump(
        #     './info/duel_dqn_{0}_weights_{1}LS_{2}_{3}_{4}.info'.format(ENV_NAME, portfolio, n_long, n_short,
        #                                                             total_reward))
        # dqn.save_weights(
        #     './model/duel_dqn_{0}_weights_{1}LS_{2}_{3}_{4}.h5f'.format(ENV_NAME, portfolio, n_long, n_short, total_reward),
        #     overwrite=True)
        # except KeyboardInterrupt:
        #     continue
        break

# %% [markdown]
# # **Execute**

# %%
if __name__ == '__main__':
  main()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 20, 64)            4288
#
#  max_pooling1d (MaxPooling1D  (None, 10, 64)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 10, 32)            6176
#
#  max_pooling1d_1 (MaxPooling  (None, 5, 32)            0
#  1D)
#
#  flatten (Flatten)           (None, 160)               0
#
#  dense (Dense)               (None, 3)                 483
#
# =================================================================
# Total params: 10,947
# Trainable params: 10,947
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Training for 175110 steps ...
# start episode ... BTC_USD_30min.csv at 0
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Tick: 100/ Portfolio (krw-won): 9832.875107231877
# Long: 18
# Tick: 200/ Portfolio (krw-won): 9916.206776231853
# Long: 33
# Tick: 300/ Portfolio (krw-won): 9626.425751601886
# Long: 47
# Tick: 400/ Portfolio (krw-won): 9071.808862115195
# Long: 68
# Tick: 500/ Portfolio (krw-won): 9046.481365319602
# Long: 85
# Tick: 600/ Portfolio (krw-won): 8988.544879600988
# Long: 103
# Tick: 700/ Portfolio (krw-won): 8813.473410469693
# Long: 120
# Tick: 800/ Portfolio (krw-won): 8831.22601052435
# Long: 139
# Tick: 900/ Portfolio (krw-won): 8706.510619583582
# Long: 156
# Tick: 1000/ Portfolio (krw-won): 8440.143269340755
# Long: 168
# Tick: 1100/ Portfolio (krw-won): 8291.578643621286
# Long: 186
# Tick: 1200/ Portfolio (krw-won): 8338.540817604202
# Long: 198
# Tick: 1300/ Portfolio (krw-won): 8317.466924316937
# Long: 218
# Tick: 1400/ Portfolio (krw-won): 8204.078799086354
# Long: 238
# Tick: 1500/ Portfolio (krw-won): 8173.9634845860855
# Long: 253
# Tick: 1600/ Portfolio (krw-won): 7935.090335555682
# Long: 266
# Tick: 1700/ Portfolio (krw-won): 7906.30684843634
# Long: 284
# Tick: 1800/ Portfolio (krw-won): 7787.609727915858
# Long: 301
# Tick: 1900/ Portfolio (krw-won): 7456.144591443785
# Long: 313
# Tick: 2000/ Portfolio (krw-won): 7228.804527541552
# Long: 329
# Tick: 2100/ Portfolio (krw-won): 7461.065312118985
# Long: 345
# Tick: 2200/ Portfolio (krw-won): 7766.399222345741
# Long: 360
# Tick: 2300/ Portfolio (krw-won): 7440.29274164533
# Long: 372
# Tick: 2400/ Portfolio (krw-won): 7885.577204419944
# Long: 386
# Tick: 2500/ Portfolio (krw-won): 7757.153730932323
# Long: 405
# Tick: 2600/ Portfolio (krw-won): 7991.390662073589
# Long: 419
# Tick: 2700/ Portfolio (krw-won): 7976.164323268167
# Long: 432
# Tick: 2800/ Portfolio (krw-won): 8097.094531371808
# Long: 443
# Tick: 2900/ Portfolio (krw-won): 8014.425013057979
# Long: 457
# Tick: 3000/ Portfolio (krw-won): 8046.284516044378
# Long: 472
# Tick: 3100/ Portfolio (krw-won): 7071.35653829672
# Long: 487
# Tick: 3200/ Portfolio (krw-won): 7182.807828008365
# Long: 506
# Tick: 3300/ Portfolio (krw-won): 7125.0603947057925
# Long: 519
# Tick: 3400/ Portfolio (krw-won): 6597.167435718282
# Long: 532
# Tick: 3500/ Portfolio (krw-won): 6653.805390409186
# Long: 541
# Tick: 3600/ Portfolio (krw-won): 6423.186530622737
# Long: 558
# Tick: 3700/ Portfolio (krw-won): 6240.915085052021
# Long: 574
# Tick: 3800/ Portfolio (krw-won): 6297.077370966697
# Long: 591
# Tick: 3900/ Portfolio (krw-won): 6546.760951044869
# Long: 603
# Tick: 4000/ Portfolio (krw-won): 6414.692330372188
# Long: 619
# Tick: 4100/ Portfolio (krw-won): 7181.870307532609
# Long: 633
# Tick: 4200/ Portfolio (krw-won): 7009.016792044936
# Long: 645
# Tick: 4300/ Portfolio (krw-won): 6841.504935192519
# Long: 661
# Tick: 4400/ Portfolio (krw-won): 7026.067493919711
# Long: 674
# Tick: 4500/ Portfolio (krw-won): 7098.527688708121
# Long: 686
# Tick: 4600/ Portfolio (krw-won): 6983.443890502123
# Long: 701
# Tick: 4700/ Portfolio (krw-won): 6988.5870949744785
# Long: 715
# Tick: 4800/ Portfolio (krw-won): 7105.434301109282
# Long: 727
# Tick: 4900/ Portfolio (krw-won): 6503.672666439876
# Long: 741
# Tick: 5000/ Portfolio (krw-won): 6905.68857151057
# Long: 757
# Tick: 5100/ Portfolio (krw-won): 7066.514441502627
# Long: 776
# Tick: 5200/ Portfolio (krw-won): 7221.149663271159
# Long: 790
# Tick: 5300/ Portfolio (krw-won): 7734.038931975663
# Long: 806
# Tick: 5400/ Portfolio (krw-won): 7666.885367295634
# Long: 824
# Tick: 5500/ Portfolio (krw-won): 7823.307878057812
# Long: 841
# Tick: 5600/ Portfolio (krw-won): 8418.862683293579
# Long: 855
# Tick: 5700/ Portfolio (krw-won): 8281.560593215521
# Long: 872
# Tick: 5800/ Portfolio (krw-won): 8074.03330117414
# Long: 887
# Tick: 5900/ Portfolio (krw-won): 8017.27062473191
# Long: 903
# Tick: 6000/ Portfolio (krw-won): 7596.379511903394
# Long: 919
# Tick: 6100/ Portfolio (krw-won): 7682.828475591496
# Long: 932
# Tick: 6200/ Portfolio (krw-won): 7968.066741626236
# Long: 950
# Tick: 6300/ Portfolio (krw-won): 7795.924245215744
# Long: 967
# Tick: 6400/ Portfolio (krw-won): 8323.17136055238
# Long: 983
# Tick: 6500/ Portfolio (krw-won): 8475.719719305205
# Long: 998
# Tick: 6600/ Portfolio (krw-won): 8395.742357912482
# Long: 1015
# Tick: 6700/ Portfolio (krw-won): 8514.743843029373
# Long: 1024
# Tick: 6800/ Portfolio (krw-won): 8821.822345472878
# Long: 1037
# Tick: 6900/ Portfolio (krw-won): 8521.183915408585
# Long: 1053
# Tick: 7000/ Portfolio (krw-won): 8442.927561109216
# Long: 1063
# Tick: 7100/ Portfolio (krw-won): 8724.143270215924
# Long: 1074
# Tick: 7200/ Portfolio (krw-won): 9101.59272987901
# Long: 1090
# Tick: 7300/ Portfolio (krw-won): 8904.762081788904
# Long: 1104
# Tick: 7400/ Portfolio (krw-won): 7632.914217215933
# Long: 1123
# Tick: 7500/ Portfolio (krw-won): 7258.739823852599
# Long: 1139
# Tick: 7600/ Portfolio (krw-won): 6780.824264863156
# Long: 1154
# Tick: 7700/ Portfolio (krw-won): 6812.954537884647
# Long: 1170
# Tick: 7800/ Portfolio (krw-won): 6607.123681068209
# Long: 1191
# Tick: 7900/ Portfolio (krw-won): 6717.62104089204
# Long: 1206
# Tick: 8000/ Portfolio (krw-won): 6856.083004788779
# Long: 1223
# Tick: 8100/ Portfolio (krw-won): 6670.709943977223
# Long: 1238
# Tick: 8200/ Portfolio (krw-won): 6675.16797354413
# Long: 1252
# Tick: 8300/ Portfolio (krw-won): 6820.472025772697
# Long: 1267
# Tick: 8400/ Portfolio (krw-won): 6448.2378400439875
# Long: 1284
# Tick: 8500/ Portfolio (krw-won): 6239.341422687441
# Long: 1303
# Tick: 8600/ Portfolio (krw-won): 5809.208945060589
# Long: 1322
# Tick: 8700/ Portfolio (krw-won): 5535.275083061496
# Long: 1341
# Tick: 8800/ Portfolio (krw-won): 5097.421856263002
# Long: 1358
# Tick: 8900/ Portfolio (krw-won): 5198.1180685539275
# Long: 1375
# Tick: 9000/ Portfolio (krw-won): 5161.557692953109
# Long: 1393
# Tick: 9100/ Portfolio (krw-won): 5290.707351210261
# Long: 1409
# Tick: 9200/ Portfolio (krw-won): 5366.148067100035
# Long: 1423
# Tick: 9300/ Portfolio (krw-won): 5321.1031316711405
# Long: 1441
# Tick: 9400/ Portfolio (krw-won): 5095.201007896538
# Long: 1456
# Tick: 9500/ Portfolio (krw-won): 5170.265745149139
# Long: 1474
# Tick: 9600/ Portfolio (krw-won): 5098.110177707254
# Long: 1488
# Tick: 9700/ Portfolio (krw-won): 5438.342883064599
# Long: 1508
# Tick: 9800/ Portfolio (krw-won): 5369.089526892698
# Long: 1527
# Tick: 9900/ Portfolio (krw-won): 4596.921112423778
# Long: 1546
# Tick: 10000/ Portfolio (krw-won): 4352.06876049347
# Long: 1562
# Tick: 10100/ Portfolio (krw-won): 4087.0307654524804
# Long: 1579
# Tick: 10200/ Portfolio (krw-won): 3804.823044364056
# Long: 1593
# Tick: 10300/ Portfolio (krw-won): 3772.2772768036025
# Long: 1615
# Tick: 10400/ Portfolio (krw-won): 3830.013527043093
# Long: 1630
# Tick: 10500/ Portfolio (krw-won): 3823.5958560988133
# Long: 1649
# Tick: 10600/ Portfolio (krw-won): 3661.253862038952
# Long: 1669
# Tick: 10700/ Portfolio (krw-won): 3659.298171716929
# Long: 1685
# Tick: 10800/ Portfolio (krw-won): 3807.8817641298674
# Long: 1702
# Tick: 10900/ Portfolio (krw-won): 3834.5623843424924
# Long: 1719
# Tick: 11000/ Portfolio (krw-won): 3723.1089284378054
# Long: 1731
# Tick: 11100/ Portfolio (krw-won): 3376.703590549778
# Long: 1746
# Tick: 11200/ Portfolio (krw-won): 3360.439473878608
# Long: 1764
# Tick: 11300/ Portfolio (krw-won): 3285.263709494623
# Long: 1779
# Tick: 11400/ Portfolio (krw-won): 2965.596293977312
# Long: 1796
# Tick: 11500/ Portfolio (krw-won): 2813.5374154763326
# Long: 1813
# Tick: 11600/ Portfolio (krw-won): 2675.42839982166
# Long: 1828
# Tick: 11700/ Portfolio (krw-won): 3098.917835905608
# Long: 1847
# Tick: 11800/ Portfolio (krw-won): 3088.4773361698526
# Long: 1866
# Tick: 11900/ Portfolio (krw-won): 3039.976838771137
# Long: 1883
# Tick: 12000/ Portfolio (krw-won): 3254.062882268756
# Long: 1899
# Tick: 12100/ Portfolio (krw-won): 3320.3664892585116
# Long: 1914
# Tick: 12200/ Portfolio (krw-won): 3259.4598862113485
# Long: 1932
# Tick: 12300/ Portfolio (krw-won): 3194.025094313656
# Long: 1945
# Tick: 12400/ Portfolio (krw-won): 2986.018186183871
# Long: 1961
# Tick: 12500/ Portfolio (krw-won): 3036.594673254914
# Long: 1976
# Tick: 12600/ Portfolio (krw-won): 2843.2781318088473
# Long: 1991
# Tick: 12700/ Portfolio (krw-won): 3092.26376885736
# Long: 2010
# Tick: 12800/ Portfolio (krw-won): 2860.981698365652
# Long: 2028
# Tick: 12900/ Portfolio (krw-won): 2832.4008489895864
# Long: 2046
# Tick: 13000/ Portfolio (krw-won): 2602.142104851073
# Long: 2064
# Tick: 13100/ Portfolio (krw-won): 2419.069560334433
# Long: 2082
# Tick: 13200/ Portfolio (krw-won): 2272.66579529684
# Long: 2099
# Tick: 13300/ Portfolio (krw-won): 2422.2602953117657
# Long: 2116
# Tick: 13400/ Portfolio (krw-won): 2411.605227424855
# Long: 2134
# Tick: 13500/ Portfolio (krw-won): 2258.5687118826268
# Long: 2150
# Tick: 13600/ Portfolio (krw-won): 2363.86818550235
# Long: 2168
# Tick: 13700/ Portfolio (krw-won): 2258.4075233053127
# Long: 2183
# Tick: 13800/ Portfolio (krw-won): 2073.550153392902
# Long: 2198
# Tick: 13900/ Portfolio (krw-won): 2067.1985714912703
# Long: 2214
# Tick: 14000/ Portfolio (krw-won): 2075.008438039392
# Long: 2232
# Tick: 14100/ Portfolio (krw-won): 1935.1247189146072
# Long: 2246
# Tick: 14200/ Portfolio (krw-won): 1789.5782714650245
# Long: 2260
# Tick: 14300/ Portfolio (krw-won): 1756.3591057436947
# Long: 2277
# Tick: 14400/ Portfolio (krw-won): 1647.077413043924
# Long: 2294
# Tick: 14500/ Portfolio (krw-won): 1770.6838366783545
# Long: 2313
# Tick: 14600/ Portfolio (krw-won): 1798.4538852479025
# Long: 2325
# Tick: 14700/ Portfolio (krw-won): 1695.9563844354443
# Long: 2343
# Tick: 14800/ Portfolio (krw-won): 1743.5151116888067
# Long: 2360
# Tick: 14900/ Portfolio (krw-won): 1733.387445617302
# Long: 2377
# Tick: 15000/ Portfolio (krw-won): 1661.6347852554602
# Long: 2395
# Tick: 15100/ Portfolio (krw-won): 1580.7129994018471
# Long: 2413
# Tick: 15200/ Portfolio (krw-won): 1561.8375061834995
# Long: 2433
# Tick: 15300/ Portfolio (krw-won): 1556.202722769187
# Long: 2447
# Tick: 15400/ Portfolio (krw-won): 1449.7442545775916
# Long: 2467
# Tick: 15500/ Portfolio (krw-won): 1385.085121581567
# Long: 2482
# Tick: 15600/ Portfolio (krw-won): 1405.8704831233363
# Long: 2497
# Tick: 15700/ Portfolio (krw-won): 1391.8104819653013
# Long: 2515
# Tick: 15800/ Portfolio (krw-won): 1394.2117080520395
# Long: 2533
# Tick: 15900/ Portfolio (krw-won): 1470.8918074976855
# Long: 2548
# Tick: 16000/ Portfolio (krw-won): 1485.0614735718236
# Long: 2567
# Tick: 16100/ Portfolio (krw-won): 1440.65598648875
# Long: 2578
# Tick: 16200/ Portfolio (krw-won): 1392.6931919648232
# Long: 2596
# Tick: 16300/ Portfolio (krw-won): 1388.7194160249157
# Long: 2616
# Tick: 16400/ Portfolio (krw-won): 1349.538328003118
# Long: 2631
# Tick: 16500/ Portfolio (krw-won): 1369.3326761475614
# Long: 2651
# Tick: 16600/ Portfolio (krw-won): 1355.3059835748434
# Long: 2666
# Tick: 16700/ Portfolio (krw-won): 1350.6208394516782
# Long: 2683
# Tick: 16800/ Portfolio (krw-won): 1233.530107646708
# Long: 2700
# Tick: 16900/ Portfolio (krw-won): 1190.946452854486
# Long: 2719
# Tick: 17000/ Portfolio (krw-won): 1177.337060782781
# Long: 2736
# Tick: 17100/ Portfolio (krw-won): 1126.5195128930172
# Long: 2752
#   17163/175110: episode: 1, duration: 236.726s, episode steps: 17163, steps per second:  73, episode reward: -2.026, mean reward: -0.000 [-0.130,  0.159], mean action: 1.024 [0.000, 2.000],  loss: 0.001578, crossentropy: 1.487469, mean_q: 1.381486, mean_eps: 0.261606
# start episode ... BTC_USD_30min.csv at 0
# Tick: 100/ Portfolio (krw-won): 9987.750585593341
# Long: 14
# Tick: 200/ Portfolio (krw-won): 9844.866514847356
# Long: 31
# Tick: 300/ Portfolio (krw-won): 9658.146748175044
# Long: 47
# Tick: 400/ Portfolio (krw-won): 9367.52895343646
# Long: 59
# Tick: 500/ Portfolio (krw-won): 9253.467963944146
# Long: 75
# Tick: 600/ Portfolio (krw-won): 9202.307215691246
# Long: 91
# Tick: 700/ Portfolio (krw-won): 9065.98907595337
# Long: 102
# Tick: 800/ Portfolio (krw-won): 9167.299808690283
# Long: 121
# Tick: 900/ Portfolio (krw-won): 9068.295906393481
# Long: 136
# Tick: 1000/ Portfolio (krw-won): 9013.684436345331
# Long: 153
# Tick: 1100/ Portfolio (krw-won): 8807.688426256589
# Long: 169
# Tick: 1200/ Portfolio (krw-won): 8654.87125887174
# Long: 184
# Tick: 1300/ Portfolio (krw-won): 8744.414704913157
# Long: 200
# Tick: 1400/ Portfolio (krw-won): 8859.199369636033
# Long: 217
# Tick: 1500/ Portfolio (krw-won): 8840.402890979332
# Long: 237
# Tick: 1600/ Portfolio (krw-won): 8452.366545973828
# Long: 256
# Tick: 1700/ Portfolio (krw-won): 8213.88123249867
# Long: 272
# Tick: 1800/ Portfolio (krw-won): 8174.30416471841
# Long: 287
# Tick: 1900/ Portfolio (krw-won): 7823.507351106833
# Long: 306
# Tick: 2000/ Portfolio (krw-won): 7541.198449052894
# Long: 318
# Tick: 2100/ Portfolio (krw-won): 8085.704659519297
# Long: 336
# Tick: 2200/ Portfolio (krw-won): 7797.991391921076
# Long: 355
# Tick: 2300/ Portfolio (krw-won): 7558.209215155766
# Long: 373
# Tick: 2400/ Portfolio (krw-won): 8013.186760907596
# Long: 387
# Tick: 2500/ Portfolio (krw-won): 7921.2042646738455
# Long: 402
# Tick: 2600/ Portfolio (krw-won): 7725.089633138769
# Long: 418
# Tick: 2700/ Portfolio (krw-won): 7731.965638452398
# Long: 433
# Tick: 2800/ Portfolio (krw-won): 7590.8138532571
# Long: 453
# Tick: 2900/ Portfolio (krw-won): 7398.024713617097
# Long: 471
# Tick: 3000/ Portfolio (krw-won): 7451.558078243721
# Long: 491
# Tick: 3100/ Portfolio (krw-won): 6516.265140724525
# Long: 509
# Tick: 3200/ Portfolio (krw-won): 6727.970667230917
# Long: 524
# Tick: 3300/ Portfolio (krw-won): 6991.122608614831
# Long: 541
# Tick: 3400/ Portfolio (krw-won): 6707.975277335463
# Long: 558
# Tick: 3500/ Portfolio (krw-won): 6596.0678585776905
# Long: 576
# Tick: 3600/ Portfolio (krw-won): 6449.3397197561935
# Long: 593
# Tick: 3700/ Portfolio (krw-won): 6303.192983483051
# Long: 608
# Tick: 3800/ Portfolio (krw-won): 6168.071476744286
# Long: 625
# Tick: 3900/ Portfolio (krw-won): 6106.2320065614
# Long: 643
# Tick: 4000/ Portfolio (krw-won): 6097.579153366174
# Long: 660
# Tick: 4100/ Portfolio (krw-won): 6177.2421015963855
# Long: 677
# Tick: 4200/ Portfolio (krw-won): 6067.463592985968
# Long: 698
# Tick: 4300/ Portfolio (krw-won): 6326.124760783897
# Long: 718
# Tick: 4400/ Portfolio (krw-won): 6160.775432283332
# Long: 738
# Tick: 4500/ Portfolio (krw-won): 6327.694513790647
# Long: 754
# Tick: 4600/ Portfolio (krw-won): 6115.655438554697
# Long: 770
# Tick: 4700/ Portfolio (krw-won): 6143.149693469315
# Long: 783
# Tick: 4800/ Portfolio (krw-won): 6287.0913537730885
# Long: 800
# Tick: 4900/ Portfolio (krw-won): 6129.49683978388
# Long: 821
# Tick: 5000/ Portfolio (krw-won): 5658.925499773263
# Long: 837
# Tick: 5100/ Portfolio (krw-won): 5018.880756960356
# Long: 853
# Tick: 5200/ Portfolio (krw-won): 5529.0037855597475
# Long: 868
# Tick: 5300/ Portfolio (krw-won): 4974.289566109085
# Long: 884
# Tick: 5400/ Portfolio (krw-won): 4780.995404701274
# Long: 897
# Tick: 5500/ Portfolio (krw-won): 5038.697219753744
# Long: 913
# Tick: 5600/ Portfolio (krw-won): 4846.219453022435
# Long: 924
# Tick: 5700/ Portfolio (krw-won): 4706.908246518046
# Long: 938
# Tick: 5800/ Portfolio (krw-won): 4293.066183095617
# Long: 954
# Tick: 5900/ Portfolio (krw-won): 3939.589428089664
# Long: 971
# Tick: 6000/ Portfolio (krw-won): 3889.5238295596473
# Long: 983
# Tick: 6100/ Portfolio (krw-won): 4010.5121559693375
# Long: 994
# Tick: 6200/ Portfolio (krw-won): 4172.283708067158
# Long: 1010
# Tick: 6300/ Portfolio (krw-won): 4058.641041360898
# Long: 1027
# Tick: 6400/ Portfolio (krw-won): 4206.192849628289
# Long: 1041
# Tick: 6500/ Portfolio (krw-won): 4160.630205705654
# Long: 1061
# Tick: 6600/ Portfolio (krw-won): 4112.896656118276
# Long: 1076
# Tick: 6700/ Portfolio (krw-won): 3942.726058293507
# Long: 1091
# Tick: 6800/ Portfolio (krw-won): 4276.965638509093
# Long: 1107
# Tick: 6900/ Portfolio (krw-won): 4415.009436962727
# Long: 1123
# Tick: 7000/ Portfolio (krw-won): 4209.998486740688
# Long: 1141
# Tick: 7100/ Portfolio (krw-won): 4256.213223539317
# Long: 1158
# Tick: 7200/ Portfolio (krw-won): 4314.533729804651
# Long: 1176
# Tick: 7300/ Portfolio (krw-won): 4320.633637896503
# Long: 1195
# Tick: 7400/ Portfolio (krw-won): 4183.062165718641
# Long: 1213
# Tick: 7500/ Portfolio (krw-won): 4094.1886350054233
# Long: 1228
# Tick: 7600/ Portfolio (krw-won): 3916.6055394017485
# Long: 1247
# Tick: 7700/ Portfolio (krw-won): 4116.450485164234
# Long: 1266
# Tick: 7800/ Portfolio (krw-won): 3764.340704124403
# Long: 1284
# Tick: 7900/ Portfolio (krw-won): 3728.8991612562963
# Long: 1300
# Tick: 8000/ Portfolio (krw-won): 3863.81565416068
# Long: 1320
# Tick: 8100/ Portfolio (krw-won): 3858.350101919553
# Long: 1339
# Tick: 8200/ Portfolio (krw-won): 3994.1419569920045
# Long: 1357
# Tick: 8300/ Portfolio (krw-won): 3576.3883984552945
# Long: 1376
# Tick: 8400/ Portfolio (krw-won): 3723.500895849153
# Long: 1392
# Tick: 8500/ Portfolio (krw-won): 3791.885728053391
# Long: 1412
# Tick: 8600/ Portfolio (krw-won): 3646.716499694194
# Long: 1431
# Tick: 8700/ Portfolio (krw-won): 3611.2926460515246
# Long: 1446
# Tick: 8800/ Portfolio (krw-won): 3538.945184442844
# Long: 1463
# Tick: 8900/ Portfolio (krw-won): 3755.5576976544016
# Long: 1482
# Tick: 9000/ Portfolio (krw-won): 3763.8567524084365
# Long: 1501
# Tick: 9100/ Portfolio (krw-won): 3675.545315373961
# Long: 1516
# Tick: 9200/ Portfolio (krw-won): 3726.292282292033
# Long: 1531
# Tick: 9300/ Portfolio (krw-won): 3622.0003687652934
# Long: 1545
# Tick: 9400/ Portfolio (krw-won): 3510.7646933979427
# Long: 1556
# Tick: 9500/ Portfolio (krw-won): 3564.4478143243973
# Long: 1573
# Tick: 9600/ Portfolio (krw-won): 3651.5347072359896
# Long: 1592
# Tick: 9700/ Portfolio (krw-won): 3766.0090349312336
# Long: 1615
# Tick: 9800/ Portfolio (krw-won): 3738.7357086978755
# Long: 1638
# Tick: 9900/ Portfolio (krw-won): 3488.3078744848494
# Long: 1656
# Tick: 10000/ Portfolio (krw-won): 3463.9649036091973
# Long: 1668
# Tick: 10100/ Portfolio (krw-won): 3356.182250635692
# Long: 1683
# Tick: 10200/ Portfolio (krw-won): 3395.2302633981863
# Long: 1703
# Tick: 10300/ Portfolio (krw-won): 3459.1211129067187
# Long: 1719
# Tick: 10400/ Portfolio (krw-won): 3463.9108697305787
# Long: 1733
# Tick: 10500/ Portfolio (krw-won): 3484.7034481836577
# Long: 1748
# Tick: 10600/ Portfolio (krw-won): 3322.9804689638445
# Long: 1764
# Tick: 10700/ Portfolio (krw-won): 3161.682178041126
# Long: 1779
# Tick: 10800/ Portfolio (krw-won): 3307.287259409994
# Long: 1796
# Tick: 10900/ Portfolio (krw-won): 3264.2237456727635
# Long: 1813
# Tick: 11000/ Portfolio (krw-won): 3220.022493972544
# Long: 1829
# Tick: 11100/ Portfolio (krw-won): 3095.396610673776
# Long: 1844
# Tick: 11200/ Portfolio (krw-won): 3006.9169293657637
# Long: 1862
# Tick: 11300/ Portfolio (krw-won): 2609.4310803376966
# Long: 1878
# Tick: 11400/ Portfolio (krw-won): 2617.8100707584463
# Long: 1895
# Tick: 11500/ Portfolio (krw-won): 2711.4843011841176
# Long: 1912
# Tick: 11600/ Portfolio (krw-won): 2453.667593804386
# Long: 1933
# Tick: 11700/ Portfolio (krw-won): 2664.223620960441
# Long: 1952
# Tick: 11800/ Portfolio (krw-won): 2791.693038199086
# Long: 1968
# Tick: 11900/ Portfolio (krw-won): 2701.234969942948
# Long: 1985
# Tick: 12000/ Portfolio (krw-won): 2789.6596299288885
# Long: 2001
# Tick: 12100/ Portfolio (krw-won): 2809.489513713566
# Long: 2018
# Tick: 12200/ Portfolio (krw-won): 2900.248173400426
# Long: 2040
# Tick: 12300/ Portfolio (krw-won): 2898.913544011325
# Long: 2054
# Tick: 12400/ Portfolio (krw-won): 2886.5320144565617
# Long: 2068
# Tick: 12500/ Portfolio (krw-won): 2920.300331406284
# Long: 2087
# Tick: 12600/ Portfolio (krw-won): 2825.079957458598
# Long: 2099
# Tick: 12700/ Portfolio (krw-won): 2995.0599560939995
# Long: 2116
# Tick: 12800/ Portfolio (krw-won): 2985.1305886602377
# Long: 2132
# Tick: 12900/ Portfolio (krw-won): 2802.888030164526
# Long: 2146
# Tick: 13000/ Portfolio (krw-won): 2553.512972351856
# Long: 2161
# Tick: 13100/ Portfolio (krw-won): 2589.3306983206894
# Long: 2179
# Tick: 13200/ Portfolio (krw-won): 2493.29608175824
# Long: 2197
# Tick: 13300/ Portfolio (krw-won): 2595.858288727744
# Long: 2213
# Tick: 13400/ Portfolio (krw-won): 2596.241974986657
# Long: 2230
# Tick: 13500/ Portfolio (krw-won): 2522.616331365547
# Long: 2248
# Tick: 13600/ Portfolio (krw-won): 2549.4885487671118
# Long: 2265
# Tick: 13700/ Portfolio (krw-won): 2430.644699746539
# Long: 2281
# Tick: 13800/ Portfolio (krw-won): 2323.564494104464
# Long: 2301
# Tick: 13900/ Portfolio (krw-won): 2277.3775176358727
# Long: 2320
# Tick: 14000/ Portfolio (krw-won): 2244.0476682331637
# Long: 2339
# Tick: 14100/ Portfolio (krw-won): 2172.99991348326
# Long: 2354
# Tick: 14200/ Portfolio (krw-won): 2079.3821505128412
# Long: 2374
# Tick: 14300/ Portfolio (krw-won): 2043.340326630176
# Long: 2392
# Tick: 14400/ Portfolio (krw-won): 2057.9899310695046
# Long: 2410
# Tick: 14500/ Portfolio (krw-won): 2110.715688923468
# Long: 2429
# Tick: 14600/ Portfolio (krw-won): 2124.813121878689
# Long: 2450
# Tick: 14700/ Portfolio (krw-won): 2162.5444170065134
# Long: 2473
# Tick: 14800/ Portfolio (krw-won): 2243.0251776446325
# Long: 2489
# Tick: 14900/ Portfolio (krw-won): 2174.2878001867502
# Long: 2507
# Tick: 15000/ Portfolio (krw-won): 2041.7798323551988
# Long: 2527
# Tick: 15100/ Portfolio (krw-won): 1949.0695973410936
# Long: 2542
# Tick: 15200/ Portfolio (krw-won): 1996.4871645486699
# Long: 2556
# Tick: 15300/ Portfolio (krw-won): 2044.6091549426585
# Long: 2570
# Tick: 15400/ Portfolio (krw-won): 2016.2023160746655
# Long: 2586
# Tick: 15500/ Portfolio (krw-won): 2009.7977979875725
# Long: 2605
# Tick: 15600/ Portfolio (krw-won): 2117.403312633301
# Long: 2627
# Tick: 15700/ Portfolio (krw-won): 2127.3120063685897
# Long: 2643
# Tick: 15800/ Portfolio (krw-won): 2122.1911597313597
# Long: 2662
# Tick: 15900/ Portfolio (krw-won): 2128.6254821960874
# Long: 2681
# Tick: 16000/ Portfolio (krw-won): 2183.149545675938
# Long: 2697
# Tick: 16100/ Portfolio (krw-won): 2152.572748551902
# Long: 2712
# Tick: 16200/ Portfolio (krw-won): 2109.2515181453123
# Long: 2729
# Tick: 16300/ Portfolio (krw-won): 2177.6410584567316
# Long: 2744
# Tick: 16400/ Portfolio (krw-won): 2087.431418713829
# Long: 2761
# Tick: 16500/ Portfolio (krw-won): 2046.6593381780888
# Long: 2777
# Tick: 16600/ Portfolio (krw-won): 2076.4822178309314
# Long: 2796
# Tick: 16700/ Portfolio (krw-won): 2067.5164245089995
# Long: 2812
# Tick: 16800/ Portfolio (krw-won): 1820.023656505977
# Long: 2832
# Tick: 16900/ Portfolio (krw-won): 1803.420852205989
# Long: 2851
# Tick: 17000/ Portfolio (krw-won): 1742.4831375037404
# Long: 2870
# Tick: 17100/ Portfolio (krw-won): 1746.8950168691424
# Long: 2887
#   34326/175110: episode: 2, duration: 237.279s, episode steps: 17163, steps per second:  72, episode reward: -1.584, mean reward: -0.000 [-0.080,  0.074], mean action: 0.996 [0.000, 2.000],  loss: 0.000120, crossentropy: 0.369466, mean_q: 0.345042, mean_eps: 0.200000
# start episode ... BTC_USD_30min.csv at 0
# Tick: 100/ Portfolio (krw-won): 10072.80945898073
# Long: 19
# Tick: 200/ Portfolio (krw-won): 10104.522601732036
# Long: 34
# Tick: 300/ Portfolio (krw-won): 9854.509999878912
# Long: 53
# Tick: 400/ Portfolio (krw-won): 9709.227691900984
# Long: 71
# Tick: 500/ Portfolio (krw-won): 9714.872707378983
# Long: 88
# Tick: 600/ Portfolio (krw-won): 9655.67296405685
# Long: 108
# Tick: 700/ Portfolio (krw-won): 9593.670290120337
# Long: 127
# Tick: 800/ Portfolio (krw-won): 9780.889875575329
# Long: 145
# Tick: 900/ Portfolio (krw-won): 9769.317717255775
# Long: 162
# Tick: 1000/ Portfolio (krw-won): 9436.560908189023
# Long: 182
# Tick: 1100/ Portfolio (krw-won): 9193.627773177335
# Long: 194
# Tick: 1200/ Portfolio (krw-won): 9106.182490465393
# Long: 207
# Tick: 1300/ Portfolio (krw-won): 9217.726984447036
# Long: 222
# Tick: 1400/ Portfolio (krw-won): 9871.97491939735
# Long: 240
# Tick: 1500/ Portfolio (krw-won): 9870.545375128131
# Long: 259
# Tick: 1600/ Portfolio (krw-won): 9202.544984947515
# Long: 277
# Tick: 1700/ Portfolio (krw-won): 9449.074699645987
# Long: 295
# Tick: 1800/ Portfolio (krw-won): 9405.388698532408
# Long: 315
# Tick: 1900/ Portfolio (krw-won): 8665.670833576405
# Long: 332
# Tick: 2000/ Portfolio (krw-won): 8840.160356509212
# Long: 344
# Tick: 2100/ Portfolio (krw-won): 9190.497536872439
# Long: 358
# Tick: 2200/ Portfolio (krw-won): 9251.331279583796
# Long: 372
# Tick: 2300/ Portfolio (krw-won): 8963.33376176415
# Long: 386
# Tick: 2400/ Portfolio (krw-won): 9219.315012835877
# Long: 404
# Tick: 2500/ Portfolio (krw-won): 9041.180666901148
# Long: 419
# Tick: 2600/ Portfolio (krw-won): 8872.540652492693
# Long: 433
# Tick: 2700/ Portfolio (krw-won): 8544.465952553857
# Long: 455
# Tick: 2800/ Portfolio (krw-won): 8826.29092129893
# Long: 472
# Tick: 2900/ Portfolio (krw-won): 8446.769094514952
# Long: 485
# Tick: 3000/ Portfolio (krw-won): 8596.101236199866
# Long: 500
# Tick: 3100/ Portfolio (krw-won): 8086.389408434731
# Long: 516
# Tick: 3200/ Portfolio (krw-won): 8002.208080369906
# Long: 532
# Tick: 3300/ Portfolio (krw-won): 8067.664265088316
# Long: 554
# Tick: 3400/ Portfolio (krw-won): 7966.634337824453
# Long: 571
# Tick: 3500/ Portfolio (krw-won): 8031.079445243226
# Long: 587
# Tick: 3600/ Portfolio (krw-won): 7721.795019434235
# Long: 609
# Tick: 3700/ Portfolio (krw-won): 7907.320178890829
# Long: 625
# Tick: 3800/ Portfolio (krw-won): 7927.643839484752
# Long: 641
# Tick: 3900/ Portfolio (krw-won): 7637.912104291074
# Long: 660
# Tick: 4000/ Portfolio (krw-won): 7546.207794361175
# Long: 678
# Tick: 4100/ Portfolio (krw-won): 8610.683736171195
# Long: 696
# Tick: 4200/ Portfolio (krw-won): 8634.317653744714
# Long: 714
# Tick: 4300/ Portfolio (krw-won): 7874.572935228966
# Long: 733
# Tick: 4400/ Portfolio (krw-won): 7610.153548176618
# Long: 750
# Tick: 4500/ Portfolio (krw-won): 7652.318708895527
# Long: 767
# Tick: 4600/ Portfolio (krw-won): 7801.176698310328
# Long: 786
# Tick: 4700/ Portfolio (krw-won): 8028.495757777443
# Long: 802
# Tick: 4800/ Portfolio (krw-won): 8081.2688552010895
# Long: 821
# Tick: 4900/ Portfolio (krw-won): 8989.921057358388
# Long: 839
# Tick: 5000/ Portfolio (krw-won): 8593.105262455214
# Long: 853
# Tick: 5100/ Portfolio (krw-won): 9445.793044619308
# Long: 871
# Tick: 5200/ Portfolio (krw-won): 9728.088868831883
# Long: 890
# Tick: 5300/ Portfolio (krw-won): 9496.666235791263
# Long: 905
# Tick: 5400/ Portfolio (krw-won): 9111.626887270846
# Long: 923
# Tick: 5500/ Portfolio (krw-won): 9630.693490824398
# Long: 938
# Tick: 5600/ Portfolio (krw-won): 8858.701999240559
# Long: 956
# Tick: 5700/ Portfolio (krw-won): 8361.624950616659
# Long: 971
# Tick: 5800/ Portfolio (krw-won): 8238.033368640574
# Long: 987
# Tick: 5900/ Portfolio (krw-won): 7760.106341368362
# Long: 1005
# Tick: 6000/ Portfolio (krw-won): 7828.720558799162
# Long: 1022
# Tick: 6100/ Portfolio (krw-won): 8070.020226032333
# Long: 1037
# Tick: 6200/ Portfolio (krw-won): 8097.528478732522
# Long: 1050
# Tick: 6300/ Portfolio (krw-won): 8040.44182039177
# Long: 1070
# Tick: 6400/ Portfolio (krw-won): 8223.425090769257
# Long: 1088
# Tick: 6500/ Portfolio (krw-won): 8422.193399031286
# Long: 1105
# Tick: 6600/ Portfolio (krw-won): 8443.743208439404
# Long: 1121
# Tick: 6700/ Portfolio (krw-won): 9101.041024562155
# Long: 1136
# Tick: 6800/ Portfolio (krw-won): 9250.45385842431
# Long: 1151
# Tick: 6900/ Portfolio (krw-won): 9250.400081036587
# Long: 1169
# Tick: 7000/ Portfolio (krw-won): 9041.813149785405
# Long: 1185
# Tick: 7100/ Portfolio (krw-won): 9288.56551384218
# Long: 1199
# Tick: 7200/ Portfolio (krw-won): 9038.90651036642
# Long: 1213
# Tick: 7300/ Portfolio (krw-won): 8891.821064474781
# Long: 1232
# Tick: 7400/ Portfolio (krw-won): 8275.143452107137
# Long: 1245
# Tick: 7500/ Portfolio (krw-won): 8287.645418841861
# Long: 1264
# Tick: 7600/ Portfolio (krw-won): 7780.900337210371
# Long: 1281
# Tick: 7700/ Portfolio (krw-won): 7956.8854784312025
# Long: 1298
# Tick: 7800/ Portfolio (krw-won): 7586.874810096337
# Long: 1313
# Tick: 7900/ Portfolio (krw-won): 7980.994500775807
# Long: 1328
# Tick: 8000/ Portfolio (krw-won): 8261.747647654614
# Long: 1344
# Tick: 8100/ Portfolio (krw-won): 8327.201873752278
# Long: 1361
# Tick: 8200/ Portfolio (krw-won): 8565.812288972238
# Long: 1376
# Tick: 8300/ Portfolio (krw-won): 7833.335054715736
# Long: 1394
# Tick: 8400/ Portfolio (krw-won): 8084.121391749897
# Long: 1411
# Tick: 8500/ Portfolio (krw-won): 7757.5191430867535
# Long: 1424
# Tick: 8600/ Portfolio (krw-won): 7537.326636660097
# Long: 1438
# Tick: 8700/ Portfolio (krw-won): 7435.931361640462
# Long: 1453
# Tick: 8800/ Portfolio (krw-won): 7387.275331440393
# Long: 1471
# Tick: 8900/ Portfolio (krw-won): 7295.216639860727
# Long: 1490
# Tick: 9000/ Portfolio (krw-won): 7305.59257414669
# Long: 1506
# Tick: 9100/ Portfolio (krw-won): 6948.384538362961
# Long: 1523
# Tick: 9200/ Portfolio (krw-won): 6990.013720012029
# Long: 1543
# Tick: 9300/ Portfolio (krw-won): 6862.561044788552
# Long: 1560
# Tick: 9400/ Portfolio (krw-won): 6545.6024777082175
# Long: 1577
# Tick: 9500/ Portfolio (krw-won): 6481.195852132978
# Long: 1598
# Tick: 9600/ Portfolio (krw-won): 6586.866686801633
# Long: 1611
# Tick: 9700/ Portfolio (krw-won): 6704.68566349176
# Long: 1627
# Tick: 9800/ Portfolio (krw-won): 6595.157047362802
# Long: 1643
# Tick: 9900/ Portfolio (krw-won): 5749.397012870114
# Long: 1655
# Tick: 10000/ Portfolio (krw-won): 5818.07136577371
# Long: 1674
# Tick: 10100/ Portfolio (krw-won): 5842.334175545093
# Long: 1690
# Tick: 10200/ Portfolio (krw-won): 5853.19608793829
# Long: 1704
# Tick: 10300/ Portfolio (krw-won): 5813.571943652816
# Long: 1723
# Tick: 10400/ Portfolio (krw-won): 5693.503445013951
# Long: 1739
# Tick: 10500/ Portfolio (krw-won): 5752.912470826719
# Long: 1757
# Tick: 10600/ Portfolio (krw-won): 5784.179644798123
# Long: 1770
# Tick: 10700/ Portfolio (krw-won): 5352.816240062417
# Long: 1789
# Tick: 10800/ Portfolio (krw-won): 5379.63251695129
# Long: 1808
# Tick: 10900/ Portfolio (krw-won): 5549.979128536619
# Long: 1825
# Tick: 11000/ Portfolio (krw-won): 5255.551213584971
# Long: 1843
# Tick: 11100/ Portfolio (krw-won): 5029.590768682507
# Long: 1859
# Tick: 11200/ Portfolio (krw-won): 4652.484299307933
# Long: 1873
# Tick: 11300/ Portfolio (krw-won): 4400.382783385604
# Long: 1888
# Tick: 11400/ Portfolio (krw-won): 3845.530868137313
# Long: 1905
# Tick: 11500/ Portfolio (krw-won): 4285.2036971578955
# Long: 1922
# Tick: 11600/ Portfolio (krw-won): 3866.126327959931
# Long: 1942
# Tick: 11700/ Portfolio (krw-won): 4350.036546449747
# Long: 1953
# Tick: 11800/ Portfolio (krw-won): 4555.524147747709
# Long: 1970
# Tick: 11900/ Portfolio (krw-won): 4531.909461797118
# Long: 1988
# Tick: 12000/ Portfolio (krw-won): 4565.175257691172
# Long: 2006
# Tick: 12100/ Portfolio (krw-won): 4519.519947362686
# Long: 2023
# Tick: 12200/ Portfolio (krw-won): 4413.468288910361
# Long: 2039
# Tick: 12300/ Portfolio (krw-won): 4396.925291809694
# Long: 2054
# Tick: 12400/ Portfolio (krw-won): 3817.2196971148182
# Long: 2070
# Tick: 12500/ Portfolio (krw-won): 4087.21389894491
# Long: 2088
# Tick: 12600/ Portfolio (krw-won): 4042.787324128753
# Long: 2105
# Tick: 12700/ Portfolio (krw-won): 4258.972454673362
# Long: 2122
# Tick: 12800/ Portfolio (krw-won): 4214.746894559299
# Long: 2137
# Tick: 12900/ Portfolio (krw-won): 4206.856688384603
# Long: 2155
# Tick: 13000/ Portfolio (krw-won): 3798.349224899172
# Long: 2170
# Tick: 13100/ Portfolio (krw-won): 3375.516067801639
# Long: 2183
# Tick: 13200/ Portfolio (krw-won): 3061.4934663541117
# Long: 2201
# Tick: 13300/ Portfolio (krw-won): 3347.4861142174973
# Long: 2221
# Tick: 13400/ Portfolio (krw-won): 3388.6402519198195
# Long: 2235
# Tick: 13500/ Portfolio (krw-won): 3142.096345552926
# Long: 2247
# Tick: 13600/ Portfolio (krw-won): 3177.8646912099684
# Long: 2261
# Tick: 13700/ Portfolio (krw-won): 2920.532468925966
# Long: 2278
# Tick: 13800/ Portfolio (krw-won): 2684.7901829268367
# Long: 2296
# Tick: 13900/ Portfolio (krw-won): 2736.3371126950733
# Long: 2311
# Tick: 14000/ Portfolio (krw-won): 2739.290326349131
# Long: 2328
# Tick: 14100/ Portfolio (krw-won): 2580.834439978333
# Long: 2347
# Tick: 14200/ Portfolio (krw-won): 2484.5681821084886
# Long: 2365
# Tick: 14300/ Portfolio (krw-won): 2523.652547559186
# Long: 2383
# Tick: 14400/ Portfolio (krw-won): 2341.6463905113796
# Long: 2396
# Tick: 14500/ Portfolio (krw-won): 2383.72602236234
# Long: 2414
# Tick: 14600/ Portfolio (krw-won): 2430.0587751902144
# Long: 2433
# Tick: 14700/ Portfolio (krw-won): 2529.666291795757
# Long: 2448
# Tick: 14800/ Portfolio (krw-won): 2538.3808726195393
# Long: 2464
# Tick: 14900/ Portfolio (krw-won): 2607.752488545935
# Long: 2482
# Tick: 15000/ Portfolio (krw-won): 2561.298805556853
# Long: 2497
# Tick: 15100/ Portfolio (krw-won): 2458.3914507520467
# Long: 2515
# Tick: 15200/ Portfolio (krw-won): 2647.25170321291
# Long: 2531
# Tick: 15300/ Portfolio (krw-won): 2670.0613779368023
# Long: 2547
# Tick: 15400/ Portfolio (krw-won): 2663.2159637591994
# Long: 2566
# Tick: 15500/ Portfolio (krw-won): 2587.580956735668
# Long: 2580
# Tick: 15600/ Portfolio (krw-won): 2569.6561495067217
# Long: 2597
# Tick: 15700/ Portfolio (krw-won): 2521.261588035465
# Long: 2615
# Tick: 15800/ Portfolio (krw-won): 2477.5763494613275
# Long: 2629
# Tick: 15900/ Portfolio (krw-won): 2524.2399031357872
# Long: 2647
# Tick: 16000/ Portfolio (krw-won): 2561.706072316679
# Long: 2668
# Tick: 16100/ Portfolio (krw-won): 2554.4638183043826
# Long: 2691
# Tick: 16200/ Portfolio (krw-won): 2469.953630773004
# Long: 2708
# Tick: 16300/ Portfolio (krw-won): 2453.1738839302247
# Long: 2726
# Tick: 16400/ Portfolio (krw-won): 2376.7726472898676
# Long: 2747
# Tick: 16500/ Portfolio (krw-won): 2365.5859486860877
# Long: 2767
# Tick: 16600/ Portfolio (krw-won): 2398.696050872615
# Long: 2783
# Tick: 16700/ Portfolio (krw-won): 2420.4314915970867
# Long: 2798
# Tick: 16800/ Portfolio (krw-won): 2165.414871377691
# Long: 2815
# Tick: 16900/ Portfolio (krw-won): 2107.6155549601226
# Long: 2834
# Tick: 17000/ Portfolio (krw-won): 2115.0530438744477
# Long: 2851
# Tick: 17100/ Portfolio (krw-won): 2141.4852365976267
# Long: 2872
#   51489/175110: episode: 3, duration: 237.515s, episode steps: 17163, steps per second:  72, episode reward: -1.362, mean reward: -0.000 [-0.094,  0.094], mean action: 0.997 [0.000, 2.000],  loss: 0.000105, crossentropy: 0.146581, mean_q: 0.141798, mean_eps: 0.200000
# start episode ... BTC_USD_30min.csv at 0
# Tick: 100/ Portfolio (krw-won): 9693.604725787012
# Long: 17
# Tick: 200/ Portfolio (krw-won): 9750.428313030983
# Long: 33
# Tick: 300/ Portfolio (krw-won): 9525.568256735145
# Long: 50
# Tick: 400/ Portfolio (krw-won): 9217.287325398647
# Long: 67
# Tick: 500/ Portfolio (krw-won): 9160.76301438326
# Long: 85
# Tick: 600/ Portfolio (krw-won): 9195.128147619307
# Long: 104
# Tick: 700/ Portfolio (krw-won): 9109.28474317989
# Long: 118
# Tick: 800/ Portfolio (krw-won): 8974.016712600085
# Long: 130
# Tick: 900/ Portfolio (krw-won): 8903.99905434638
# Long: 143
# Tick: 1000/ Portfolio (krw-won): 8666.74421402796
# Long: 159
# Tick: 1100/ Portfolio (krw-won): 8492.898688804973
# Long: 173
# Tick: 1200/ Portfolio (krw-won): 8347.287838222379
# Long: 187
# Tick: 1300/ Portfolio (krw-won): 8290.711259657826
# Long: 206
# Tick: 1400/ Portfolio (krw-won): 8632.780614399824
# Long: 225
# Tick: 1500/ Portfolio (krw-won): 8592.350579782558
# Long: 240
# Tick: 1600/ Portfolio (krw-won): 8274.946401433637
# Long: 258
# Tick: 1700/ Portfolio (krw-won): 8283.578975100714
# Long: 280
# Tick: 1800/ Portfolio (krw-won): 8352.116082782666
# Long: 299
# Tick: 1900/ Portfolio (krw-won): 8158.751077368636
# Long: 315
# Tick: 2000/ Portfolio (krw-won): 8385.94103246424
# Long: 331
# Tick: 2100/ Portfolio (krw-won): 8402.865066454713
# Long: 348
# Tick: 2200/ Portfolio (krw-won): 8273.429514631382
# Long: 365
# Tick: 2300/ Portfolio (krw-won): 8146.204684283173
# Long: 382
# Tick: 2400/ Portfolio (krw-won): 7902.538962033846
# Long: 400
# Tick: 2500/ Portfolio (krw-won): 7582.6968315964505
# Long: 419
# Tick: 2600/ Portfolio (krw-won): 7786.947636962575
# Long: 436
# Tick: 2700/ Portfolio (krw-won): 8292.634207077766
# Long: 454
# Tick: 2800/ Portfolio (krw-won): 8565.848778816606
# Long: 476
# Tick: 2900/ Portfolio (krw-won): 8222.453130080614
# Long: 495
# Tick: 3000/ Portfolio (krw-won): 8036.210007120639
# Long: 516
# Tick: 3100/ Portfolio (krw-won): 7080.480904681905
# Long: 533
# Tick: 3200/ Portfolio (krw-won): 7481.314369676413
# Long: 552
# Tick: 3300/ Portfolio (krw-won): 7547.281508583435
# Long: 569
# Tick: 3400/ Portfolio (krw-won): 7726.766880096504
# Long: 591
# Tick: 3500/ Portfolio (krw-won): 7526.421566801003
# Long: 606
# Tick: 3600/ Portfolio (krw-won): 7289.320887889895
# Long: 626
# Tick: 3700/ Portfolio (krw-won): 6872.676889745731
# Long: 646
# Tick: 3800/ Portfolio (krw-won): 6479.275451507839
# Long: 664
# Tick: 3900/ Portfolio (krw-won): 6460.597942699916
# Long: 685
# Tick: 4000/ Portfolio (krw-won): 6398.88164161091
# Long: 701
# Tick: 4100/ Portfolio (krw-won): 7320.519411373088
# Long: 720
# Tick: 4200/ Portfolio (krw-won): 7334.76885922248
# Long: 738
# Tick: 4300/ Portfolio (krw-won): 7449.036626395086
# Long: 755
# Tick: 4400/ Portfolio (krw-won): 6755.665175759469
# Long: 774
# Tick: 4500/ Portfolio (krw-won): 6775.088844445891
# Long: 793
# Tick: 4600/ Portfolio (krw-won): 6960.543975599455
# Long: 812
# Tick: 4700/ Portfolio (krw-won): 6665.70652841469
# Long: 828
# Tick: 4800/ Portfolio (krw-won): 6917.876141679301
# Long: 848
# Tick: 4900/ Portfolio (krw-won): 7124.307532594292
# Long: 866
# Tick: 5000/ Portfolio (krw-won): 6638.6719893003
# Long: 887
# Tick: 5100/ Portfolio (krw-won): 7027.7441054368
# Long: 906
# Tick: 5200/ Portfolio (krw-won): 6595.69870763421
# Long: 925
# Tick: 5300/ Portfolio (krw-won): 6366.368858054688
# Long: 942
# Tick: 5400/ Portfolio (krw-won): 6396.125536031105
# Long: 960
# Tick: 5500/ Portfolio (krw-won): 5997.855380274847
# Long: 977
# Tick: 5600/ Portfolio (krw-won): 5646.46014689563
# Long: 997
# Tick: 5700/ Portfolio (krw-won): 5510.8476539902185
# Long: 1016
# Tick: 5800/ Portfolio (krw-won): 5183.097117304797
# Long: 1034
# Tick: 5900/ Portfolio (krw-won): 4596.02091422313
# Long: 1051
# Tick: 6000/ Portfolio (krw-won): 4472.592605700074
# Long: 1067
# Tick: 6100/ Portfolio (krw-won): 4681.5472171049605
# Long: 1084
# Tick: 6200/ Portfolio (krw-won): 5158.4747652988735
# Long: 1104
# Tick: 6300/ Portfolio (krw-won): 5281.547673437765
# Long: 1120
# Tick: 6400/ Portfolio (krw-won): 5659.544647734268
# Long: 1138
# Tick: 6500/ Portfolio (krw-won): 5556.261136852133
# Long: 1157
# Tick: 6600/ Portfolio (krw-won): 5180.694379693373
# Long: 1174
# Tick: 6700/ Portfolio (krw-won): 5839.072089131494
# Long: 1193
# Tick: 6800/ Portfolio (krw-won): 6350.4307558944465
# Long: 1210
# Tick: 6900/ Portfolio (krw-won): 6340.730382682179
# Long: 1230
# Tick: 7000/ Portfolio (krw-won): 6314.033551747434
# Long: 1247
# Tick: 7100/ Portfolio (krw-won): 6538.544596901301
# Long: 1261
# Tick: 7200/ Portfolio (krw-won): 6614.06911798292
# Long: 1275
# Tick: 7300/ Portfolio (krw-won): 6032.260996727151
# Long: 1294
# Tick: 7400/ Portfolio (krw-won): 5939.543184181165
# Long: 1313
# Tick: 7500/ Portfolio (krw-won): 5639.213139903277
# Long: 1330
# Tick: 7600/ Portfolio (krw-won): 5170.735158733721
# Long: 1347
# Tick: 7700/ Portfolio (krw-won): 5351.517336439696
# Long: 1366
# Tick: 7800/ Portfolio (krw-won): 5557.375661594399
# Long: 1385
# Tick: 7900/ Portfolio (krw-won): 5549.958654393316
# Long: 1403
# Tick: 8000/ Portfolio (krw-won): 5425.3370617418395
# Long: 1421
# Tick: 8100/ Portfolio (krw-won): 5413.988122794766
# Long: 1440
# Tick: 8200/ Portfolio (krw-won): 5789.16490498506
# Long: 1456
# Tick: 8300/ Portfolio (krw-won): 5321.09460821924
# Long: 1473
# Tick: 8400/ Portfolio (krw-won): 5296.85453488132
# Long: 1492
# Tick: 8500/ Portfolio (krw-won): 5320.977803317202
# Long: 1513
# Tick: 8600/ Portfolio (krw-won): 5177.526809843936
# Long: 1533
# Tick: 8700/ Portfolio (krw-won): 5001.5246282822345
# Long: 1548
# Tick: 8800/ Portfolio (krw-won): 4642.742579611655
# Long: 1563
# Tick: 8900/ Portfolio (krw-won): 4729.991637749942
# Long: 1582
# Tick: 9000/ Portfolio (krw-won): 4713.622324705895
# Long: 1600
# Tick: 9100/ Portfolio (krw-won): 4795.684609220612
# Long: 1620
# Tick: 9200/ Portfolio (krw-won): 4703.8218101171
# Long: 1643
# Tick: 9300/ Portfolio (krw-won): 4745.486732020744
# Long: 1665
# Tick: 9400/ Portfolio (krw-won): 4606.421901787875
# Long: 1682
# Tick: 9500/ Portfolio (krw-won): 4649.175629609373
# Long: 1701
# Tick: 9600/ Portfolio (krw-won): 4539.504376115539
# Long: 1716
# Tick: 9700/ Portfolio (krw-won): 4578.8658485501455
# Long: 1736
# Tick: 9800/ Portfolio (krw-won): 4338.641629652874
# Long: 1755
# Tick: 9900/ Portfolio (krw-won): 4075.6382396970603
# Long: 1776
# Tick: 10000/ Portfolio (krw-won): 4072.7554114148124
# Long: 1796
# Tick: 10100/ Portfolio (krw-won): 4158.126260599391
# Long: 1816
# Tick: 10200/ Portfolio (krw-won): 3953.089368840898
# Long: 1838
# Tick: 10300/ Portfolio (krw-won): 4042.671524687304
# Long: 1858
# Tick: 10400/ Portfolio (krw-won): 4117.89913928613
# Long: 1877
# Tick: 10500/ Portfolio (krw-won): 4140.854678660898
# Long: 1897
# Tick: 10600/ Portfolio (krw-won): 4109.559767052921
# Long: 1916
# Tick: 10700/ Portfolio (krw-won): 3905.487922169243
# Long: 1932
# Tick: 10800/ Portfolio (krw-won): 4023.7652856215987
# Long: 1948
# Tick: 10900/ Portfolio (krw-won): 4043.160421957315
# Long: 1967
# Tick: 11000/ Portfolio (krw-won): 3853.0932940419852
# Long: 1980
# Tick: 11100/ Portfolio (krw-won): 3646.309299412622
# Long: 2000
# Tick: 11200/ Portfolio (krw-won): 3469.0290787648096
# Long: 2018
# Tick: 11300/ Portfolio (krw-won): 3021.777388516872
# Long: 2035
# Tick: 11400/ Portfolio (krw-won): 2906.679108332123
# Long: 2049
# Tick: 11500/ Portfolio (krw-won): 3235.8447176533655
# Long: 2067
# Tick: 11600/ Portfolio (krw-won): 3227.2690126051994
# Long: 2085
# Tick: 11700/ Portfolio (krw-won): 3287.783229706205
# Long: 2101
# Tick: 11800/ Portfolio (krw-won): 3347.4503077567115
# Long: 2116
# Tick: 11900/ Portfolio (krw-won): 2982.7464107206606
# Long: 2131
# Tick: 12000/ Portfolio (krw-won): 3136.5885230324425
# Long: 2150
# Tick: 12100/ Portfolio (krw-won): 3134.6064534190973
# Long: 2166
# Tick: 12200/ Portfolio (krw-won): 2916.218380718777
# Long: 2179
# Tick: 12300/ Portfolio (krw-won): 2908.096706726927
# Long: 2195
# Tick: 12400/ Portfolio (krw-won): 2729.7646685954724
# Long: 2211
# Tick: 12500/ Portfolio (krw-won): 2932.282835663536
# Long: 2231
# Tick: 12600/ Portfolio (krw-won): 2975.298907711755
# Long: 2248
# Tick: 12700/ Portfolio (krw-won): 3093.4246115809774
# Long: 2263
# Tick: 12800/ Portfolio (krw-won): 2962.734577271971
# Long: 2279
# Tick: 12900/ Portfolio (krw-won): 2634.298888032188
# Long: 2295
# Tick: 13000/ Portfolio (krw-won): 2456.815928141335
# Long: 2312
# Tick: 13100/ Portfolio (krw-won): 2488.4984321732263
# Long: 2335
# Tick: 13200/ Portfolio (krw-won): 2540.0922518916022
# Long: 2351
# Tick: 13300/ Portfolio (krw-won): 2789.430633699222
# Long: 2367
# Tick: 13400/ Portfolio (krw-won): 2848.3280651976984
# Long: 2382
# Tick: 13500/ Portfolio (krw-won): 2697.7996508831343
# Long: 2398
# Tick: 13600/ Portfolio (krw-won): 2713.308883929573
# Long: 2415
# Tick: 13700/ Portfolio (krw-won): 2574.4148849664084
# Long: 2434
# Tick: 13800/ Portfolio (krw-won): 2526.8699027230855
# Long: 2448
# Tick: 13900/ Portfolio (krw-won): 2533.8808898789007
# Long: 2465
# Tick: 14000/ Portfolio (krw-won): 2418.9573663652063
# Long: 2485
# Tick: 14100/ Portfolio (krw-won): 2288.7071529354976
# Long: 2501
# Tick: 14200/ Portfolio (krw-won): 2242.340127672284
# Long: 2518
# Tick: 14300/ Portfolio (krw-won): 2215.3117018609564
# Long: 2533
# Tick: 14400/ Portfolio (krw-won): 2079.466668669458
# Long: 2549
# Tick: 14500/ Portfolio (krw-won): 2088.2791186211584
# Long: 2566
# Tick: 14600/ Portfolio (krw-won): 2115.4279061171324
# Long: 2580
# Tick: 14700/ Portfolio (krw-won): 2119.2294660406683
# Long: 2598
# Tick: 14800/ Portfolio (krw-won): 1998.2252697738238
# Long: 2617
# Tick: 14900/ Portfolio (krw-won): 1933.8751769288951
# Long: 2636
# Tick: 15000/ Portfolio (krw-won): 1935.5595219511183
# Long: 2654
# Tick: 15100/ Portfolio (krw-won): 1903.1086052637081
# Long: 2673
# Tick: 15200/ Portfolio (krw-won): 1957.9883130449982
# Long: 2689
# Tick: 15300/ Portfolio (krw-won): 2043.940287452145
# Long: 2709
# Tick: 15400/ Portfolio (krw-won): 2130.783542740742
# Long: 2725
# Tick: 15500/ Portfolio (krw-won): 2082.7289895689414
# Long: 2742
# Tick: 15600/ Portfolio (krw-won): 2078.858673705876
# Long: 2762
# Tick: 15700/ Portfolio (krw-won): 2069.431938541622
# Long: 2778
# Tick: 15800/ Portfolio (krw-won): 2049.3486154567877
# Long: 2795
# Tick: 15900/ Portfolio (krw-won): 2059.6789359599643
# Long: 2813
# Tick: 16000/ Portfolio (krw-won): 2014.6269924903138
# Long: 2832
# Tick: 16100/ Portfolio (krw-won): 1911.7384919696274
# Long: 2852
# Tick: 16200/ Portfolio (krw-won): 1826.6943891929618
# Long: 2865
# Tick: 16300/ Portfolio (krw-won): 1845.159749498895
# Long: 2880
# Tick: 16400/ Portfolio (krw-won): 1816.6781185226664
# Long: 2898
# Tick: 16500/ Portfolio (krw-won): 1937.8026568003133
# Long: 2917
# Tick: 16600/ Portfolio (krw-won): 1980.1843787012124
# Long: 2934
# Tick: 16700/ Portfolio (krw-won): 1973.5537425558975
# Long: 2950
# Tick: 16800/ Portfolio (krw-won): 1704.2576807725638
# Long: 2965
# Tick: 16900/ Portfolio (krw-won): 1714.6661406338296
# Long: 2979
# Tick: 17000/ Portfolio (krw-won): 1691.7431698332534
# Long: 2994
# Tick: 17100/ Portfolio (krw-won): 1709.7032044438804
# Long: 3012
#   68652/175110: episode: 4, duration: 238.259s, episode steps: 17163, steps per second:  72, episode reward: -1.569, mean reward: -0.000 [-0.080,  0.109], mean action: 0.983 [0.000, 2.000],  loss: 0.000090, crossentropy: 0.090642, mean_q: 0.090170, mean_eps: 0.200000
# start episode ... BTC_USD_30min.csv at 0
# Tick: 100/ Portfolio (krw-won): 9955.771278966711
# Long: 15
# Tick: 200/ Portfolio (krw-won): 9920.979566528093
# Long: 35
# Tick: 300/ Portfolio (krw-won): 9650.576270817137
# Long: 51
# Tick: 400/ Portfolio (krw-won): 9115.450612521454
# Long: 64
# Tick: 500/ Portfolio (krw-won): 9091.01264648601
# Long: 82
# Tick: 600/ Portfolio (krw-won): 9059.410007183158
# Long: 97
# Tick: 700/ Portfolio (krw-won): 8916.516197089031
# Long: 113
# Tick: 800/ Portfolio (krw-won): 9088.926520967332
# Long: 126
# Tick: 900/ Portfolio (krw-won): 9070.570032344134
# Long: 141
# Tick: 1000/ Portfolio (krw-won): 8836.439089694468
# Long: 157
# Tick: 1100/ Portfolio (krw-won): 8606.83928845463
# Long: 172
# Tick: 1200/ Portfolio (krw-won): 8594.005469335323
# Long: 188
# Tick: 1300/ Portfolio (krw-won): 8588.322821710877
# Long: 201
# Tick: 1400/ Portfolio (krw-won): 8986.738530987253
# Long: 220
# Tick: 1500/ Portfolio (krw-won): 8981.971676466675
# Long: 232
# Tick: 1600/ Portfolio (krw-won): 8762.135979830993
# Long: 250
# Tick: 1700/ Portfolio (krw-won): 8828.853483715717
# Long: 264
# Tick: 1800/ Portfolio (krw-won): 8885.991168669905
# Long: 282
# Tick: 1900/ Portfolio (krw-won): 8785.972326093088
# Long: 298
# Tick: 2000/ Portfolio (krw-won): 8458.3361177794
# Long: 315
# Tick: 2100/ Portfolio (krw-won): 8926.395102662043
# Long: 330
# Tick: 2200/ Portfolio (krw-won): 8817.490143157609
# Long: 347
# Tick: 2300/ Portfolio (krw-won): 8950.971462211299
# Long: 364
# Tick: 2400/ Portfolio (krw-won): 9303.900387848713
# Long: 381
# Tick: 2500/ Portfolio (krw-won): 9278.948244803136
# Long: 401
# Tick: 2600/ Portfolio (krw-won): 9219.067620708815
# Long: 415
# Tick: 2700/ Portfolio (krw-won): 9448.826652921382
# Long: 435
# Tick: 2800/ Portfolio (krw-won): 9485.376946993834
# Long: 450
# Tick: 2900/ Portfolio (krw-won): 9505.446343273017
# Long: 465
# Tick: 3000/ Portfolio (krw-won): 9931.061246795234
# Long: 487
# Tick: 3100/ Portfolio (krw-won): 9023.102397355275
# Long: 506
# Tick: 3200/ Portfolio (krw-won): 8865.207612643713
# Long: 523
# ...
# Long: 2869
#  154467/175110: episode: 9, duration: 241.700s, episode steps: 17163, steps per second:  71, episode reward: -1.227, mean reward: -0.000 [-0.099,  0.145], mean action: 1.008 [0.000, 2.000],  loss: 0.000100, crossentropy: 0.089501, mean_q: 0.088222, mean_eps: 0.200000
# start episode ... BTC_USD_30min.csv at 0
# Tick: 100/ Portfolio (krw-won): 9975.679365560563
# Long: 18
# Tick: 200/ Portfolio (krw-won): 9996.562009737658
# Long: 36
# Tick: 300/ Portfolio (krw-won): 9894.895761462349
# Long: 56
# Tick: 400/ Portfolio (krw-won): 9720.045823228149
# Long: 73
# Tick: 500/ Portfolio (krw-won): 9622.561972603273
# Long: 90
# Tick: 600/ Portfolio (krw-won): 9507.83515064348
# Long: 105
# Tick: 700/ Portfolio (krw-won): 9194.585314837537
# Long: 122
# Tick: 800/ Portfolio (krw-won): 9518.805002171375
# Long: 141
# Tick: 900/ Portfolio (krw-won): 9566.589384139148
# Long: 163
# Tick: 1000/ Portfolio (krw-won): 9225.525068841385
# Long: 181
# Tick: 1100/ Portfolio (krw-won): 9001.461686765593
# Long: 202
# Tick: 1200/ Portfolio (krw-won): 8790.581323669825
# Long: 220
# Tick: 1300/ Portfolio (krw-won): 8525.855562081962
# Long: 240
# Tick: 1400/ Portfolio (krw-won): 8880.571243539109
# Long: 256
# Tick: 1500/ Portfolio (krw-won): 8925.854670924651
# Long: 274
# Tick: 1600/ Portfolio (krw-won): 8866.957831692504
# Long: 290
# Tick: 1700/ Portfolio (krw-won): 9013.61957600476
# Long: 307
# Tick: 1800/ Portfolio (krw-won): 9189.93730446333
# Long: 327
# Tick: 1900/ Portfolio (krw-won): 9074.1404951477
# Long: 346
# Tick: 2000/ Portfolio (krw-won): 9245.245692645596
# Long: 362
# Tick: 2100/ Portfolio (krw-won): 9799.055029655601
# Long: 378
# Tick: 2200/ Portfolio (krw-won): 9436.914797658148
# Long: 396
# Tick: 2300/ Portfolio (krw-won): 9405.578480510107
# Long: 417
# Tick: 2400/ Portfolio (krw-won): 9274.386282244495
# Long: 437
# Tick: 2500/ Portfolio (krw-won): 8993.611494777346
# Long: 450
# Tick: 2600/ Portfolio (krw-won): 9130.247778233035
# Long: 468
# Tick: 2700/ Portfolio (krw-won): 9042.560214460978
# Long: 485
# Tick: 2800/ Portfolio (krw-won): 9424.574684520272
# Long: 502
# Tick: 2900/ Portfolio (krw-won): 9192.483198681623
# Long: 522
# Tick: 3000/ Portfolio (krw-won): 9008.646548657085
# Long: 541
# Tick: 3100/ Portfolio (krw-won): 8888.146411189451
# Long: 559
# Tick: 3200/ Portfolio (krw-won): 9138.607309572782
# Long: 576
# Tick: 3300/ Portfolio (krw-won): 9831.103834039082
# Long: 595
# Tick: 3400/ Portfolio (krw-won): 9522.86589679541
# Long: 612
# Tick: 3500/ Portfolio (krw-won): 9302.362491821144
# Long: 630
# Tick: 3600/ Portfolio (krw-won): 8833.737168286816
# Long: 650
# Tick: 3700/ Portfolio (krw-won): 8878.811794181878
# Long: 669
# Tick: 3800/ Portfolio (krw-won): 8662.928733539271
# Long: 685
# Tick: 3900/ Portfolio (krw-won): 8590.2350513752
# Long: 702
# Tick: 4000/ Portfolio (krw-won): 8577.715528642413
# Long: 717
# Tick: 4100/ Portfolio (krw-won): 9103.41865414541
# Long: 733
# Tick: 4200/ Portfolio (krw-won): 8952.78241983539
# Long: 753
# Tick: 4300/ Portfolio (krw-won): 8687.854396950837
# Long: 770
# Tick: 4400/ Portfolio (krw-won): 8400.902874211124
# Long: 783
# Tick: 4500/ Portfolio (krw-won): 8558.482807231912
# Long: 802
# Tick: 4600/ Portfolio (krw-won): 8296.877976294007
# Long: 817
# Tick: 4700/ Portfolio (krw-won): 7864.677073038436
# Long: 832
# Tick: 4800/ Portfolio (krw-won): 7904.007049920055
# Long: 847
# Tick: 4900/ Portfolio (krw-won): 8565.28620006858
# Long: 860
# Tick: 5000/ Portfolio (krw-won): 8426.030560359472
# Long: 875
# Tick: 5100/ Portfolio (krw-won): 8925.934182362
# Long: 893
# Tick: 5200/ Portfolio (krw-won): 8940.724235779666
# Long: 913
# Tick: 5300/ Portfolio (krw-won): 8605.426251903134
# Long: 930
# Tick: 5400/ Portfolio (krw-won): 7804.864954645565
# Long: 949
# Tick: 5500/ Portfolio (krw-won): 8423.610710868406
# Long: 966
# Tick: 5600/ Portfolio (krw-won): 8585.140092369074
# Long: 985
# Tick: 5700/ Portfolio (krw-won): 7985.773779599577
# Long: 1004
# Tick: 5800/ Portfolio (krw-won): 7250.007728229149
# Long: 1023
# Tick: 5900/ Portfolio (krw-won): 7662.128324352604
# Long: 1040
# Tick: 6000/ Portfolio (krw-won): 7348.230868934955
# Long: 1059
# Tick: 6100/ Portfolio (krw-won): 7178.621763236139
# Long: 1075
# Tick: 6200/ Portfolio (krw-won): 7630.941557324098
# Long: 1090
# Tick: 6300/ Portfolio (krw-won): 7054.633294913847
# Long: 1109
# Tick: 6400/ Portfolio (krw-won): 7098.957856125602
# Long: 1127
# Tick: 6500/ Portfolio (krw-won): 6961.1101462707065
# Long: 1142
# Tick: 6600/ Portfolio (krw-won): 6877.589658482546
# Long: 1157
# Tick: 6700/ Portfolio (krw-won): 6944.398101670039
# Long: 1174
# Tick: 6800/ Portfolio (krw-won): 6730.8681985518915
# Long: 1190
# Tick: 6900/ Portfolio (krw-won): 7003.968717977545
# Long: 1208
# Tick: 7000/ Portfolio (krw-won): 6885.189782250109
# Long: 1228
# Tick: 7100/ Portfolio (krw-won): 7089.646067129532
# Long: 1244
# Tick: 7200/ Portfolio (krw-won): 7483.383922709385
# Long: 1264
# Tick: 7300/ Portfolio (krw-won): 7227.703266953719
# Long: 1281
# Tick: 7400/ Portfolio (krw-won): 7421.454732311615
# Long: 1298
# Tick: 7500/ Portfolio (krw-won): 6487.795951613867
# Long: 1317
# Tick: 7600/ Portfolio (krw-won): 6392.267557147933
# Long: 1335
# Tick: 7700/ Portfolio (krw-won): 6787.194934144917
# Long: 1353
# Tick: 7800/ Portfolio (krw-won): 6688.990433059028
# Long: 1370
# Tick: 7900/ Portfolio (krw-won): 6943.215587761128
# Long: 1387
# Tick: 8000/ Portfolio (krw-won): 6986.000168057178
# Long: 1406
# Tick: 8100/ Portfolio (krw-won): 7180.37935405703
# Long: 1423
# Tick: 8200/ Portfolio (krw-won): 6974.154815216109
# Long: 1440
# Tick: 8300/ Portfolio (krw-won): 6544.392872072574
# Long: 1455
# Tick: 8400/ Portfolio (krw-won): 6234.05211853718
# Long: 1470
# Tick: 8500/ Portfolio (krw-won): 6451.799209749693
# Long: 1489
# Tick: 8600/ Portfolio (krw-won): 6073.556458451741
# Long: 1504
# Tick: 8700/ Portfolio (krw-won): 6064.7293517751295
# Long: 1521
# Tick: 8800/ Portfolio (krw-won): 5701.850055418638
# Long: 1541
# Tick: 8900/ Portfolio (krw-won): 5889.835731521683
# Long: 1561
# Tick: 9000/ Portfolio (krw-won): 5990.530277143702
# Long: 1573
# Tick: 9100/ Portfolio (krw-won): 5994.85835501885
# Long: 1591
# Tick: 9200/ Portfolio (krw-won): 5841.557941780992
# Long: 1612
# Tick: 9300/ Portfolio (krw-won): 5679.819177930017
# Long: 1628
# Tick: 9400/ Portfolio (krw-won): 5352.8752276053265
# Long: 1643
# Tick: 9500/ Portfolio (krw-won): 5405.204624971474
# Long: 1661
# Tick: 9600/ Portfolio (krw-won): 5365.174074325708
# Long: 1678
# Tick: 9700/ Portfolio (krw-won): 5646.893793841227
# Long: 1693
# Tick: 9800/ Portfolio (krw-won): 5486.297140521902
# Long: 1711
# Tick: 9900/ Portfolio (krw-won): 4875.981588072832
# Long: 1728
# Tick: 10000/ Portfolio (krw-won): 4906.905334216511
# Long: 1745
# Tick: 10100/ Portfolio (krw-won): 4821.600148515776
# Long: 1760
# Tick: 10200/ Portfolio (krw-won): 4715.80005215232
# Long: 1780
# Tick: 10300/ Portfolio (krw-won): 4878.374739407872
# Long: 1795
# Tick: 10400/ Portfolio (krw-won): 4887.678248033633
# Long: 1814
# Tick: 10500/ Portfolio (krw-won): 5037.679652322928
# Long: 1830
# Tick: 10600/ Portfolio (krw-won): 4895.56994878159
# Long: 1846
# Tick: 10700/ Portfolio (krw-won): 4627.0763971185925
# Long: 1862
# Tick: 10800/ Portfolio (krw-won): 4747.6886065448
# Long: 1878
# Tick: 10900/ Portfolio (krw-won): 4799.994184381878
# Long: 1897
# Tick: 11000/ Portfolio (krw-won): 4448.343053103816
# Long: 1909
# Tick: 11100/ Portfolio (krw-won): 4197.781247695909
# Long: 1926
# Tick: 11200/ Portfolio (krw-won): 4312.953314654164
# Long: 1940
# Tick: 11300/ Portfolio (krw-won): 4136.732129423207
# Long: 1956
# Tick: 11400/ Portfolio (krw-won): 4010.1164043278686
# Long: 1973
# Tick: 11500/ Portfolio (krw-won): 3888.1227858355683
# Long: 1993
# Tick: 11600/ Portfolio (krw-won): 3573.8211247298536
# Long: 2007
# Tick: 11700/ Portfolio (krw-won): 3494.7643774510475
# Long: 2027
# Tick: 11800/ Portfolio (krw-won): 3560.380117485668
# Long: 2044
# Tick: 11900/ Portfolio (krw-won): 3458.752426396656
# Long: 2061
# Tick: 12000/ Portfolio (krw-won): 3628.1154513683477
# Long: 2078
# Tick: 12100/ Portfolio (krw-won): 3553.4968238832344
# Long: 2098
# Tick: 12200/ Portfolio (krw-won): 3503.0174445604716
# Long: 2117
# Tick: 12300/ Portfolio (krw-won): 3253.6435341256893
# Long: 2135
# Tick: 12400/ Portfolio (krw-won): 3175.1613203000834
# Long: 2155
# Tick: 12500/ Portfolio (krw-won): 3314.742440125776
# Long: 2175
# Tick: 12600/ Portfolio (krw-won): 2970.162107264694
# Long: 2189
# Tick: 12700/ Portfolio (krw-won): 3057.3223118349424
# Long: 2207
# Tick: 12800/ Portfolio (krw-won): 3034.936172033054
# Long: 2220
# Tick: 12900/ Portfolio (krw-won): 3072.685594096008
# Long: 2237
# Tick: 13000/ Portfolio (krw-won): 2748.675250865081
# Long: 2253
# Tick: 13100/ Portfolio (krw-won): 2492.367804035735
# Long: 2272
# Tick: 13200/ Portfolio (krw-won): 2478.1432916114827
# Long: 2293
# Tick: 13300/ Portfolio (krw-won): 2622.172846960634
# Long: 2307
# Tick: 13400/ Portfolio (krw-won): 2563.6653785128565
# Long: 2318
# Tick: 13500/ Portfolio (krw-won): 2353.2713257434775
# Long: 2338
# Tick: 13600/ Portfolio (krw-won): 2422.10095607181
# Long: 2353
# Tick: 13700/ Portfolio (krw-won): 2355.0477174373723
# Long: 2370
# Tick: 13800/ Portfolio (krw-won): 2219.372359749135
# Long: 2390
# Tick: 13900/ Portfolio (krw-won): 2275.4839888608735
# Long: 2409
# Tick: 14000/ Portfolio (krw-won): 2233.4997113430727
# Long: 2430
# Tick: 14100/ Portfolio (krw-won): 2132.7227643676038
# Long: 2449
# Tick: 14200/ Portfolio (krw-won): 2034.331333335071
# Long: 2465
# Tick: 14300/ Portfolio (krw-won): 2045.173425929309
# Long: 2480
# Tick: 14400/ Portfolio (krw-won): 1895.991099593202
# Long: 2497
# Tick: 14500/ Portfolio (krw-won): 1931.3328757801758
# Long: 2513
# Tick: 14600/ Portfolio (krw-won): 1986.22350607121
# Long: 2532
# Tick: 14700/ Portfolio (krw-won): 1989.7943832578526
# Long: 2549
# Tick: 14800/ Portfolio (krw-won): 2141.9984210289063
# Long: 2570
# Tick: 14900/ Portfolio (krw-won): 2138.932087957483
# Long: 2587
# Tick: 15000/ Portfolio (krw-won): 2048.501823052777
# Long: 2605
# Tick: 15100/ Portfolio (krw-won): 1910.1936837555768
# Long: 2621
# Tick: 15200/ Portfolio (krw-won): 1999.4362602614056
# Long: 2636
# Tick: 15300/ Portfolio (krw-won): 1971.8943454274329
# Long: 2655
# Tick: 15400/ Portfolio (krw-won): 1956.0147165098224
# Long: 2671
# Tick: 15500/ Portfolio (krw-won): 1867.5855495243502
# Long: 2685
# Tick: 15600/ Portfolio (krw-won): 2003.352932889612
# Long: 2704
# Tick: 15700/ Portfolio (krw-won): 1941.1796166430847
# Long: 2716
# Tick: 15800/ Portfolio (krw-won): 1868.2415814408212
# Long: 2735
# Tick: 15900/ Portfolio (krw-won): 1856.8427541521994
# Long: 2752
# Tick: 16000/ Portfolio (krw-won): 1890.4978153517422
# Long: 2769
# Tick: 16100/ Portfolio (krw-won): 1783.1476134115483
# Long: 2784
# Tick: 16200/ Portfolio (krw-won): 1790.5473766613502
# Long: 2798
# Tick: 16300/ Portfolio (krw-won): 1822.6699664453256
# Long: 2810
# Tick: 16400/ Portfolio (krw-won): 1828.4035983216402
# Long: 2823
# Tick: 16500/ Portfolio (krw-won): 1823.4448840236025
# Long: 2837
# Tick: 16600/ Portfolio (krw-won): 1695.6357844456581
# Long: 2854
# Tick: 16700/ Portfolio (krw-won): 1692.6982391248737
# Long: 2873
# Tick: 16800/ Portfolio (krw-won): 1643.0335045418938
# Long: 2894
# Tick: 16900/ Portfolio (krw-won): 1665.9052097909414
# Long: 2909
# Tick: 17000/ Portfolio (krw-won): 1636.6213482822784
# Long: 2927
# Tick: 17100/ Portfolio (krw-won): 1657.763671724245
# Long: 2945
#  171630/175110: episode: 10, duration: 238.015s, episode steps: 17163, steps per second:  72, episode reward: -1.633, mean reward: -0.000 [-0.067,  0.075], mean action: 0.984 [0.000, 2.000],  loss: 0.000097, crossentropy: 0.091694, mean_q: 0.090223, mean_eps: 0.200000
# start episode ... BTC_USD_30min.csv at 0
# Tick: 100/ Portfolio (krw-won): 9776.519834657498
# Long: 19
# Tick: 200/ Portfolio (krw-won): 9654.282319977103
# Long: 34
# Tick: 300/ Portfolio (krw-won): 9427.5395216388
# Long: 52
# Tick: 400/ Portfolio (krw-won): 9141.533006869453
# Long: 72
# Tick: 500/ Portfolio (krw-won): 9044.598815798337
# Long: 87
# Tick: 600/ Portfolio (krw-won): 9057.747965315408
# Long: 104
# Tick: 700/ Portfolio (krw-won): 8794.712591790974
# Long: 123
# Tick: 800/ Portfolio (krw-won): 8770.6440809458
# Long: 140
# Tick: 900/ Portfolio (krw-won): 8695.04334935602
# Long: 155
# Tick: 1000/ Portfolio (krw-won): 8480.922207804597
# Long: 168
# Tick: 1100/ Portfolio (krw-won): 8261.662540517253
# Long: 185
# Tick: 1200/ Portfolio (krw-won): 8197.381409840882
# Long: 200
# Tick: 1300/ Portfolio (krw-won): 8334.949991707634
# Long: 219
# Tick: 1400/ Portfolio (krw-won): 8552.144183398588
# Long: 236
# Tick: 1500/ Portfolio (krw-won): 8475.969419443472
# Long: 252
# Tick: 1600/ Portfolio (krw-won): 8184.6792439936935
# Long: 270
# Tick: 1700/ Portfolio (krw-won): 8061.42242056705
# Long: 283
# Tick: 1800/ Portfolio (krw-won): 7966.042672562916
# Long: 300
# Tick: 1900/ Portfolio (krw-won): 7459.973857094072
# Long: 317
# Tick: 2000/ Portfolio (krw-won): 7370.3714490193815
# Long: 337
# Tick: 2100/ Portfolio (krw-won): 7633.557883074876
# Long: 352
# Tick: 2200/ Portfolio (krw-won): 7580.235984738178
# Long: 373
# Tick: 2300/ Portfolio (krw-won): 7426.665450123531
# Long: 389
# Tick: 2400/ Portfolio (krw-won): 7646.592236858623
# Long: 405
# Tick: 2500/ Portfolio (krw-won): 7448.907709792475
# Long: 426
# Tick: 2600/ Portfolio (krw-won): 7469.727753830825
# Long: 444
# Tick: 2700/ Portfolio (krw-won): 7553.2427842419975
# Long: 465
# Tick: 2800/ Portfolio (krw-won): 7508.125731200146
# Long: 484
# Tick: 2900/ Portfolio (krw-won): 7303.617267025
# Long: 502
# Tick: 3000/ Portfolio (krw-won): 7022.273386265058
# Long: 520
# Tick: 3100/ Portfolio (krw-won): 6884.825671421978
# Long: 539
# Tick: 3200/ Portfolio (krw-won): 7174.1547716626765
# Long: 557
# Tick: 3300/ Portfolio (krw-won): 7507.428749044641
# Long: 575
# Tick: 3400/ Portfolio (krw-won): 7415.724588556673
# Long: 595
# done, took 2432.541 seconds
# Testing for 1 episodes ...
# start episode ... BTC_USD_30min.csv at 0
# Tick: 100/ Portfolio (krw-won): 10005.327123074156
# Long: 5
# Tick: 200/ Portfolio (krw-won): 10005.327123074156
# Long: 5
# Tick: 300/ Portfolio (krw-won): 10005.327123074156
# Long: 5
# Tick: 400/ Portfolio (krw-won): 10005.327123074156
# Long: 5
# Tick: 500/ Portfolio (krw-won): 10005.327123074156
# Long: 5
# Tick: 600/ Portfolio (krw-won): 10039.326442504314
# Long: 7
# Tick: 700/ Portfolio (krw-won): 10039.326442504314
# Long: 7
# Tick: 800/ Portfolio (krw-won): 10039.326442504314
# Long: 7
# Tick: 900/ Portfolio (krw-won): 10039.326442504314
# Long: 7
# Tick: 1000/ Portfolio (krw-won): 10039.326442504314
# Long: 7
# Tick: 1100/ Portfolio (krw-won): 10080.62440512478
# Long: 9
# Tick: 1200/ Portfolio (krw-won): 10099.811742317374
# Long: 10
# Tick: 1300/ Portfolio (krw-won): 10104.792267535278
# Long: 12
# Tick: 1400/ Portfolio (krw-won): 10104.792267535278
# Long: 12
# Tick: 1500/ Portfolio (krw-won): 10237.620328886625
# Long: 13
# Tick: 1600/ Portfolio (krw-won): 10237.620328886625
# Long: 13
# Tick: 1700/ Portfolio (krw-won): 10237.620328886625
# Long: 13
# Tick: 1800/ Portfolio (krw-won): 10237.620328886625
# Long: 13
# Tick: 1900/ Portfolio (krw-won): 10237.620328886625
# Long: 13
# Tick: 2000/ Portfolio (krw-won): 10237.620328886625
# Long: 13
# Tick: 2100/ Portfolio (krw-won): 10175.373301676367
# Long: 14
# Tick: 2200/ Portfolio (krw-won): 10175.373301676367
# Long: 14
# Tick: 2300/ Portfolio (krw-won): 10090.10775295597
# Long: 15
# Tick: 2400/ Portfolio (krw-won): 10090.10775295597
# Long: 15
# Tick: 2500/ Portfolio (krw-won): 10090.10775295597
# Long: 15
# Tick: 2600/ Portfolio (krw-won): 10190.054029126666
# Long: 17
# Tick: 2700/ Portfolio (krw-won): 10190.054029126666
# Long: 17
# Tick: 2800/ Portfolio (krw-won): 10203.395015338372
# Long: 18
# Tick: 2900/ Portfolio (krw-won): 10140.305407615086
# Long: 19
# Tick: 3000/ Portfolio (krw-won): 10173.974002431964
# Long: 20
# Tick: 3100/ Portfolio (krw-won): 10173.974002431964
# Long: 20
# Tick: 3200/ Portfolio (krw-won): 10159.661062791163
# Long: 21
# Tick: 3300/ Portfolio (krw-won): 10171.015763367725
# Long: 22
# Tick: 3400/ Portfolio (krw-won): 10171.015763367725
# Long: 22
# Tick: 3500/ Portfolio (krw-won): 10171.015763367725
# Long: 22
# Tick: 3600/ Portfolio (krw-won): 10143.059182874013
# Long: 23
# Tick: 3700/ Portfolio (krw-won): 10143.059182874013
# Long: 23
# Tick: 3800/ Portfolio (krw-won): 9588.668228040407
# Long: 24
# Tick: 3900/ Portfolio (krw-won): 9540.808778843317
# Long: 25
# Tick: 4000/ Portfolio (krw-won): 9540.808778843317
# Long: 25
# Tick: 4100/ Portfolio (krw-won): 10140.613520714398
# Long: 26
# Tick: 4200/ Portfolio (krw-won): 10140.613520714398
# Long: 26
# Episode 1: reward: 0.018, steps: 4203

# %% [markdown]
# # **Scratch**

# %%
dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')

raw_df= pd.read_csv('data/test/BTC_USD_1h.csv', 
    parse_dates=['date'], date_parser=dateparse)
raw_df = raw_df.sort_values(by='date').reset_index(drop=True)

print(raw_df[0:10])
